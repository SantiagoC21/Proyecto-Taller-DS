# %%
# !pip3 install pysd

# %%
import os
from pysd import read_vensim
import pandas as pd
import re

# %%
def parse_mdl_file(filepath):
    variables = []
    connections = []
    variable_ids = set()  # Para evitar duplicados

    with open(filepath, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    for line in lines:
        parts = line.strip().split(',')

        if not parts or len(parts) < 5:
            continue

        prefix = parts[0]

        if prefix in ['10', '11', '12']:  # Variable
            try:
                tipo = {
                    '10': 'auxiliary',
                    '11': 'stock',
                    '12': 'flow'
                }[prefix]

                vid = f"v{parts[1]}"
                name = parts[2].strip('"')

                if name == '0' or name.strip() == '':
                    continue  # Ignorar nombres inválidos

                if vid in variable_ids:
                    continue  # Ignorar duplicados

                x = int(parts[3])
                y = int(parts[4])

                variables.append({
                    "id": vid,
                    "name": name,
                    "type": tipo,
                    "x": x,
                    "y": y
                })

                variable_ids.add(vid)

            except Exception as e:
                print("[ERROR variable] Línea inválida:", line.strip(), "→", e)
                continue

        elif prefix == '1':  # Conexión
            try:
                cid = f"c{parts[1]}"
                from_id = f"v{parts[2]}"
                to_id = f"v{parts[3]}"

                text = line.strip()

                # Extraer color (primer patrón RGB)
                color_match = re.search(r"(\d+-\d+-\d+)", text)
                color = color_match.group(1) if color_match else None

                # Determinar polaridad según color
                if color == "0-0-255":
                    polarity = "positive"
                elif color == "255-0-0":
                    polarity = "negative"
                else:
                    polarity = "positive"

                # Extraer coordenadas de curva
                coord_match = re.search(r"\((\d+),(\d+)\)", text)
                if coord_match:
                    x_curve = int(coord_match.group(1))
                    y_curve = int(coord_match.group(2))
                else:
                    x_curve = None
                    y_curve = None

                connections.append({
                    "id": cid,
                    "from": from_id,
                    "to": to_id,
                    "color": color,
                    "polarity": polarity,
                    "x_curve": x_curve,
                    "y_curve": y_curve
                })

            except Exception as e:
                print("[ERROR conexión] Línea inválida:", line.strip(), "→", e)
                continue

    return {
        "name": os.path.basename(filepath),
        "variables": variables,
        "connections": connections
    }

# %%
parse_mdl_file("eficiencia-movilidad-causal.mdl")
# Out:
# {'name': 'eficiencia-movilidad-causal.mdl',
#  'variables': [{'id': 'v3',
#    'name': 'Congestión vehicular',
#    'type': 'auxiliary',
#    'x': 1301,
#    'y': 256},
#   {'id': 'v4',
#    'name': 'Eficiencia de movilidad',
#    'type': 'auxiliary',
#    'x': 1168,
#    'y': 467},
#   {'id': 'v6',
#    'name': 'Fluidez del tráfico',
#    'type': 'auxiliary',
#    'x': 880,
#    'y': 445},
#   {'id': 'v8',
#    'name': 'Uso del transporte público',
#    'type': 'auxiliary',
#    'x': 905,
#    'y': 167},
#   {'id': 'v9',
#    'name': 'Número de vehículos en circulación',
#    'type': 'auxiliary',
#    'x': 1040,
#    'y': 256},
#   {'id': 'v12',
#    'name': 'Calidad de transporte público',
#    'type': 'auxiliary',
#    'x': 733,
#    'y': 117},
#   {'id': 'v14',
#    'name': 'Extorsionesa a transportistas',
#    'type': 'auxiliary',
#    'x': 562,
#    'y': -8},
#   {'id': 'v15',
#    'name': 'Nivel de educación vial',
#    'type': 'auxiliary',
#    'x': 1565,
#    'y': -31},
#   {'id': 'v16',
#    'name': 'Total de Infracciones',
#    'type': 'auxiliary',
#    'x': 1230,
#    'y': 85},
#   {'id': 'v18',
#    'name': 'Cantidad de Transporte informal',
#    'type': 'auxiliary',
#    'x': 1541,
#    'y': 130},
#   {'id': 'v19',
#    'name': 'Paradas no autorizadas utilizadas por vehiculo',
#    'type': 'auxiliary',
#    'x': 1469,
#    'y': 208},
#   {'id': 'v23',
#    'name': 'Cruces de pistas indevidas por transeuntes',
#    'type': 'auxiliary',
#    'x': 1546,
#    'y': 337},
#   {'id': 'v26',
#    'name': 'Tasa de presión de pasajeros recibidas por conductores',
#    'type': 'auxiliary',
#    'x': 494,
#    'y': 587},
#   {'id': 'v28',
#    'name': 'Póliticas de regulación de transporte',
#    'type': 'auxiliary',
#    'x': 1407,
#    'y': 75},
#   {'id': 'v30',
#    'name': 'Uso de aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 1003,
#    'y': -25},
#   {'id': 'v33', 'name': 'Seguridad', 'type': 'auxiliary', 'x': 775, 'y': -124},
#   {'id': 'v36',
#    'name': 'Estres de transportistas',
#    'type': 'auxiliary',
#    'x': 567,
#    'y': 153},
#   {'id': 'v43',
#    'name': 'Calidad de infraestructura vial',
#    'type': 'auxiliary',
#    'x': 611,
#    'y': 379},
#   {'id': 'v46',
#    'name': 'Estratégicas de ejecución de obras',
#    'type': 'auxiliary',
#    'x': 730,
#    'y': 315},
#   {'id': 'v50',
#    'name': 'Tasa de seguridad',
#    'type': 'auxiliary',
#    'x': 678,
#    'y': -215},
#   {'id': 'v52',
#    'name': 'Tasa de infracciones',
#    'type': 'auxiliary',
#    'x': 1213,
#    'y': -71},
#   {'id': 'v54',
#    'name': 'Tasa de extorsiones a transportistas',
#    'type': 'auxiliary',
#    'x': 465,
#    'y': -123},
#   {'id': 'v56',
#    'name': 'Tasa de transeuntes que cruzan indevidamente',
#    'type': 'auxiliary',
#    'x': 1478,
#    'y': 473},
#   {'id': 'v58',
#    'name': 'Tasa de población que utiliza aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 1041,
#    'y': -157},
#   {'id': 'v60',
#    'name': 'Tasa de inversion de infraestructura',
#    'type': 'auxiliary',
#    'x': 649,
#    'y': 531},
#   {'id': 'v62',
#    'name': 'Tasa de transportes públicos en correcto estado',
#    'type': 'auxiliary',
#    'x': 799,
#    'y': 0},
#   {'id': 'v64',
#    'name': 'Tasa de vehiculos en circulación',
#    'type': 'auxiliary',
#    'x': 927,
#    'y': 338},
#   {'id': 'v66',
#    'name': 'Tasa de educacion vial de calidad',
#    'type': 'auxiliary',
#    'x': 1438,
#    'y': -120}],
#  'connections': [{'id': 'c5',
#    'from': 'v3',
#    'to': 'v4',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1227,
#    'y_curve': 457},
#   {'id': 'c7',
#    'from': 'v6',
#    'to': 'v4',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1016,
#    'y_curve': 513},
#   {'id': 'c10',
#    'from': 'v8',
#    'to': 'v9',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 932,
#    'y_curve': 235},
#   {'id': 'c11',
#    'from': 'v9',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1208,
#    'y_curve': 232},
#   {'id': 'c13',
#    'from': 'v12',
#    'to': 'v8',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 839,
#    'y_curve': 114},
#   {'id': 'c17',
#    'from': 'v16',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1281,
#    'y_curve': 126},
#   {'id': 'c20',
#    'from': 'v18',
#    'to': 'v19',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1528,
#    'y_curve': 217},
#   {'id': 'c21',
#    'from': 'v19',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1397,
#    'y_curve': 252},
#   {'id': 'c22',
#    'from': 'v15',
#    'to': 'v18',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1582,
#    'y_curve': 45},
#   {'id': 'c24',
#    'from': 'v15',
#    'to': 'v23',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1644,
#    'y_curve': 164},
#   {'id': 'c25',
#    'from': 'v23',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1400,
#    'y_curve': 317},
#   {'id': 'c27',
#    'from': 'v26',
#    'to': 'v19',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 944,
#    'y_curve': 665},
#   {'id': 'c29',
#    'from': 'v28',
#    'to': 'v18',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1496,
#    'y_curve': 68},
#   {'id': 'c31',
#    'from': 'v30',
#    'to': 'v8',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1008,
#    'y_curve': 76},
#   {'id': 'c32',
#    'from': 'v4',
#    'to': 'v30',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1120,
#    'y_curve': 218},
#   {'id': 'c34',
#    'from': 'v33',
#    'to': 'v30',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c35',
#    'from': 'v33',
#    'to': 'v14',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c37',
#    'from': 'v14',
#    'to': 'v36',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 519,
#    'y_curve': 65},
#   {'id': 'c38',
#    'from': 'v36',
#    'to': 'v12',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 640,
#    'y_curve': 105},
#   {'id': 'c39',
#    'from': 'v16',
#    'to': 'v36',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 897,
#    'y_curve': 231},
#   {'id': 'c40',
#    'from': 'v8',
#    'to': 'v30',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 903,
#    'y_curve': 64},
#   {'id': 'c41',
#    'from': 'v4',
#    'to': 'v3',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1202,
#    'y_curve': 340},
#   {'id': 'c42',
#    'from': 'v4',
#    'to': 'v6',
#    'color': '0-0-160',
#    'polarity': 'positive',
#    'x_curve': 1031,
#    'y_curve': 388},
#   {'id': 'c44',
#    'from': 'v43',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 757,
#    'y_curve': 463},
#   {'id': 'c45',
#    'from': 'v43',
#    'to': 'v36',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 548,
#    'y_curve': 254},
#   {'id': 'c47',
#    'from': 'v46',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 754,
#    'y_curve': 382},
#   {'id': 'c48',
#    'from': 'v8',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 847,
#    'y_curve': 294},
#   {'id': 'c49',
#    'from': 'v14',
#    'to': 'v33',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c51',
#    'from': 'v50',
#    'to': 'v33',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c53',
#    'from': 'v52',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1187,
#    'y_curve': 6},
#   {'id': 'c55',
#    'from': 'v54',
#    'to': 'v14',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c57',
#    'from': 'v56',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1579,
#    'y_curve': 448},
#   {'id': 'c59',
#    'from': 'v58',
#    'to': 'v30',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c61',
#    'from': 'v60',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 647,
#    'y_curve': 452},
#   {'id': 'c63',
#    'from': 'v62',
#    'to': 'v12',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 801,
#    'y_curve': 45},
#   {'id': 'c65',
#    'from': 'v64',
#    'to': 'v9',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1032,
#    'y_curve': 312},
#   {'id': 'c67',
#    'from': 'v66',
#    'to': 'v15',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c70',
#    'from': 'v26',
#    'to': 'v36',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 396,
#    'y_curve': 332}]}

# %%
parse_mdl_file("frecuencia-de-mantenimiento-forrester.mdl")
# Out:
# {'name': 'frecuencia-de-mantenimiento-forrester.mdl',
#  'variables': [{'id': 'v2',
#    'name': 'Disponibilidad de la flota',
#    'type': 'auxiliary',
#    'x': 637,
#    'y': 343},
#   {'id': 'v3', 'name': '48', 'type': 'flow', 'x': 339, 'y': 336},
#   {'id': 'v7',
#    'name': 'Vehiculos que regresan de mantenimiento',
#    'type': 'auxiliary',
#    'x': 457,
#    'y': 374},
#   {'id': 'v8', 'name': '48', 'type': 'flow', 'x': 923, 'y': 343},
#   {'id': 'v12',
#    'name': 'Vehiculos que se retiran por mantenimiento',
#    'type': 'auxiliary',
#    'x': 814,
#    'y': 385},
#   {'id': 'v13',
#    'name': 'Cantidad de vehiculos en operacion',
#    'type': 'auxiliary',
#    'x': 850,
#    'y': 582},
#   {'id': 'v17',
#    'name': 'Vehiculos asignados a operar',
#    'type': 'auxiliary',
#    'x': 707,
#    'y': 505},
#   {'id': 'v18', 'name': '48', 'type': 'flow', 'x': 1210, 'y': 589},
#   {'id': 'v22',
#    'name': 'Vehiculos devueltos al deposito',
#    'type': 'auxiliary',
#    'x': 1087,
#    'y': 623},
#   {'id': 'v23',
#    'name': 'Cantidad de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2022,
#    'y': 385},
#   {'id': 'v24', 'name': '48', 'type': 'flow', 'x': 1615, 'y': 386},
#   {'id': 'v28',
#    'name': 'Numero de veces que ocurre una falla mecanica',
#    'type': 'auxiliary',
#    'x': 1786,
#    'y': 426},
#   {'id': 'v29', 'name': '48', 'type': 'flow', 'x': 2369, 'y': 381},
#   {'id': 'v33',
#    'name': 'Reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2218,
#    'y': 413},
#   {'id': 'v34', 'name': '48', 'type': 'flow', 'x': 2120, 'y': 682},
#   {'id': 'v38',
#    'name': 'Cantidad de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2176,
#    'y': 571},
#   {'id': 'v39',
#    'name': 'Disponibilidad de talleres',
#    'type': 'auxiliary',
#    'x': 1346,
#    'y': 1151},
#   {'id': 'v40', 'name': '48', 'type': 'flow', 'x': 954, 'y': 1134},
#   {'id': 'v44',
#    'name': 'Cantidad de plazas sin asignacion de mantenimiento',
#    'type': 'auxiliary',
#    'x': 1127,
#    'y': 1170},
#   {'id': 'v45', 'name': '48', 'type': 'flow', 'x': 1679, 'y': 1150},
#   {'id': 'v49',
#    'name': 'Cantidad de plazas apartadas por mantenimiento',
#    'type': 'auxiliary',
#    'x': 1546,
#    'y': 1188},
#   {'id': 'v50',
#    'name': 'Tiempo promedio de mantenimiento',
#    'type': 'auxiliary',
#    'x': 383,
#    'y': 731},
#   {'id': 'v51',
#    'name': 'Tasa de liberacion de plazas',
#    'type': 'auxiliary',
#    'x': 748,
#    'y': 805},
#   {'id': 'v52',
#    'name': 'Cantidad de vehiculos que terminan el mantenimiento por semana',
#    'type': 'auxiliary',
#    'x': 503,
#    'y': 967},
#   {'id': 'v53',
#    'name': 'Total de plazas',
#    'type': 'auxiliary',
#    'x': 942,
#    'y': 1228},
#   {'id': 'v54',
#    'name': 'Cantidad de plazas ocupadas',
#    'type': 'auxiliary',
#    'x': 962,
#    'y': 1319},
#   {'id': 'v55',
#    'name': 'Capacidad de atencion por plaza',
#    'type': 'auxiliary',
#    'x': 1791,
#    'y': 1231},
#   {'id': 'v56',
#    'name': 'Demanda por mantenimiento',
#    'type': 'auxiliary',
#    'x': 1821,
#    'y': 1018},
#   {'id': 'v57',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento preventivo',
#    'type': 'auxiliary',
#    'x': 2135,
#    'y': 820},
#   {'id': 'v58',
#    'name': 'Proporcion de vehiculos que van a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 1612,
#    'y': 783},
#   {'id': 'v59',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 1881,
#    'y': 505},
#   {'id': 'v60',
#    'name': 'Cantidad promedio de malas maniobras por vehiculo',
#    'type': 'auxiliary',
#    'x': 1423,
#    'y': 359},
#   {'id': 'v61',
#    'name': 'Cantidad de malas maniobras',
#    'type': 'auxiliary',
#    'x': 1169,
#    'y': 334},
#   {'id': 'v62',
#    'name': 'Tasa de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 1038,
#    'y': 173},
#   {'id': 'v63',
#    'name': 'Vehiculos operativos que mostraron fallas',
#    'type': 'auxiliary',
#    'x': 951,
#    'y': 267},
#   {'id': 'v64',
#    'name': 'Tasa de inoperatividad por fallas',
#    'type': 'auxiliary',
#    'x': 841,
#    'y': 106},
#   {'id': 'v65',
#    'name': 'Total de la flota',
#    'type': 'auxiliary',
#    'x': 116,
#    'y': 394},
#   {'id': 'v66',
#    'name': 'Cantidad de vehiculos en mantenimiento',
#    'type': 'auxiliary',
#    'x': 276,
#    'y': 246},
#   {'id': 'v67',
#    'name': 'Tasa de asignacion',
#    'type': 'auxiliary',
#    'x': 493,
#    'y': 515},
#   {'id': 'v68',
#    'name': 'Tasa de retorno al deposito',
#    'type': 'auxiliary',
#    'x': 1111,
#    'y': 751},
#   {'id': 'v99',
#    'name': 'Demanda de operacion',
#    'type': 'auxiliary',
#    'x': 529,
#    'y': 649},
#   {'id': 'v103',
#    'name': 'Tasa de reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2376,
#    'y': 267},
#   {'id': 'v105',
#    'name': 'Tasa de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2281,
#    'y': 676},
#   {'id': 'v107',
#    'name': 'Objetivo2',
#    'type': 'auxiliary',
#    'x': 1864,
#    'y': 215},
#   {'id': 'v108',
#    'name': 'Discrepancia2',
#    'type': 'auxiliary',
#    'x': 1979,
#    'y': 264},
#   {'id': 'v109',
#    'name': 'Error/Faltante2',
#    'type': 'auxiliary',
#    'x': 1785,
#    'y': 291},
#   {'id': 'v114',
#    'name': 'Discrepancia1',
#    'type': 'auxiliary',
#    'x': 718,
#    'y': 169},
#   {'id': 'v115', 'name': 'Objetivo1', 'type': 'auxiliary', 'x': 589, 'y': 73},
#   {'id': 'v116',
#    'name': 'Error/Faltante1',
#    'type': 'auxiliary',
#    'x': 483,
#    'y': 191},
#   {'id': 'v117',
#    'name': 'Discrepancia3',
#    'type': 'auxiliary',
#    'x': 671,
#    'y': 644},
#   {'id': 'v118', 'name': 'Objetivo3', 'type': 'auxiliary', 'x': 781, 'y': 736},
#   {'id': 'v119',
#    'name': 'Error/Faltante3',
#    'type': 'auxiliary',
#    'x': 928,
#    'y': 663},
#   {'id': 'v126',
#    'name': 'Discrepancia4',
#    'type': 'auxiliary',
#    'x': 1339,
#    'y': 1286},
#   {'id': 'v127',
#    'name': 'Objetivo4',
#    'type': 'auxiliary',
#    'x': 1418,
#    'y': 1351},
#   {'id': 'v128',
#    'name': 'Error/Faltante4',
#    'type': 'auxiliary',
#    'x': 1552,
#    'y': 1301}],
#  'connections': [{'id': 'c4',
#    'from': 'v6',
#    'to': 'v3',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 400,
#    'y_curve': 336},
#   {'id': 'c5',
#    'from': 'v6',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 517,
#    'y_curve': 336},
#   {'id': 'c9',
#    'from': 'v11',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 755,
#    'y_curve': 343},
#   {'id': 'c10',
#    'from': 'v11',
#    'to': 'v8',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 866,
#    'y_curve': 343},
#   {'id': 'c14',
#    'from': 'v16',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 625,
#    'y_curve': 434},
#   {'id': 'c15',
#    'from': 'v16',
#    'to': 'v13',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 625,
#    'y_curve': 582},
#   {'id': 'c19',
#    'from': 'v21',
#    'to': 'v13',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1010,
#    'y_curve': 589},
#   {'id': 'c20',
#    'from': 'v21',
#    'to': 'v18',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1146,
#    'y_curve': 589},
#   {'id': 'c25',
#    'from': 'v27',
#    'to': 'v24',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1702,
#    'y_curve': 386},
#   {'id': 'c26',
#    'from': 'v27',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1869,
#    'y_curve': 386},
#   {'id': 'c30',
#    'from': 'v32',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2155,
#    'y_curve': 381},
#   {'id': 'c31',
#    'from': 'v32',
#    'to': 'v29',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2291,
#    'y_curve': 381},
#   {'id': 'c35',
#    'from': 'v37',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2046,
#    'y_curve': 488},
#   {'id': 'c36',
#    'from': 'v37',
#    'to': 'v34',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2046,
#    'y_curve': 682},
#   {'id': 'c41',
#    'from': 'v43',
#    'to': 'v40',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1056,
#    'y_curve': 1134},
#   {'id': 'c42',
#    'from': 'v43',
#    'to': 'v39',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1206,
#    'y_curve': 1134},
#   {'id': 'c46',
#    'from': 'v48',
#    'to': 'v39',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1476,
#    'y_curve': 1150},
#   {'id': 'c47',
#    'from': 'v48',
#    'to': 'v45',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1610,
#    'y_curve': 1150},
#   {'id': 'c69',
#    'from': 'v2',
#    'to': 'v66',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 483,
#    'y_curve': 223},
#   {'id': 'c70',
#    'from': 'v66',
#    'to': 'v6',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 417,
#    'y_curve': 284},
#   {'id': 'c71',
#    'from': 'v65',
#    'to': 'v66',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 227,
#    'y_curve': 364},
#   {'id': 'c72',
#    'from': 'v50',
#    'to': 'v7',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c73',
#    'from': 'v50',
#    'to': 'v51',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c74',
#    'from': 'v52',
#    'to': 'v51',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 702,
#    'y_curve': 915},
#   {'id': 'c75',
#    'from': 'v39',
#    'to': 'v54',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1221,
#    'y_curve': 1304},
#   {'id': 'c76',
#    'from': 'v55',
#    'to': 'v49',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c77',
#    'from': 'v56',
#    'to': 'v48',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1677,
#    'y_curve': 1177},
#   {'id': 'c78',
#    'from': 'v57',
#    'to': 'v56',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2024,
#    'y_curve': 952},
#   {'id': 'c79',
#    'from': 'v57',
#    'to': 'v37',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2134,
#    'y_curve': 710},
#   {'id': 'c80',
#    'from': 'v58',
#    'to': 'v57',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c81',
#    'from': 'v59',
#    'to': 'v56',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c82',
#    'from': 'v58',
#    'to': 'v59',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c83',
#    'from': 'v59',
#    'to': 'v32',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2038,
#    'y_curve': 504},
#   {'id': 'c84',
#    'from': 'v62',
#    'to': 'v27',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1567,
#    'y_curve': 124},
#   {'id': 'c85',
#    'from': 'v61',
#    'to': 'v28',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1577,
#    'y_curve': 208},
#   {'id': 'c86',
#    'from': 'v60',
#    'to': 'v61',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1292,
#    'y_curve': 397},
#   {'id': 'c87',
#    'from': 'v13',
#    'to': 'v61',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c88',
#    'from': 'v13',
#    'to': 'v21',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1008,
#    'y_curve': 556},
#   {'id': 'c89',
#    'from': 'v68',
#    'to': 'v22',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1126,
#    'y_curve': 650},
#   {'id': 'c90',
#    'from': 'v13',
#    'to': 'v63',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 962,
#    'y_curve': 437},
#   {'id': 'c91',
#    'from': 'v62',
#    'to': 'v63',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 971,
#    'y_curve': 172},
#   {'id': 'c92',
#    'from': 'v64',
#    'to': 'v11',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c93',
#    'from': 'v63',
#    'to': 'v11',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c94',
#    'from': 'v12',
#    'to': 'v59',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c95',
#    'from': 'v12',
#    'to': 'v57',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c96',
#    'from': 'v2',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 680,
#    'y_curve': 422},
#   {'id': 'c97',
#    'from': 'v67',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 560,
#    'y_curve': 471},
#   {'id': 'c98',
#    'from': 'v53',
#    'to': 'v54',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 977,
#    'y_curve': 1265},
#   {'id': 'c100',
#    'from': 'v99',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c101',
#    'from': 'v54',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1079,
#    'y_curve': 1278},
#   {'id': 'c102',
#    'from': 'v51',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c104',
#    'from': 'v103',
#    'to': 'v32',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2242,
#    'y_curve': 249},
#   {'id': 'c106',
#    'from': 'v105',
#    'to': 'v37',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c110',
#    'from': 'v107',
#    'to': 'v108',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1947,
#    'y_curve': 221},
#   {'id': 'c111',
#    'from': 'v107',
#    'to': 'v109',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1793,
#    'y_curve': 244},
#   {'id': 'c112',
#    'from': 'v23',
#    'to': 'v109',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1913,
#    'y_curve': 322},
#   {'id': 'c113',
#    'from': 'v23',
#    'to': 'v108',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c120',
#    'from': 'v2',
#    'to': 'v114',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c121',
#    'from': 'v2',
#    'to': 'v116',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 602,
#    'y_curve': 235},
#   {'id': 'c122',
#    'from': 'v115',
#    'to': 'v114',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 681,
#    'y_curve': 93},
#   {'id': 'c123',
#    'from': 'v115',
#    'to': 'v116',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 505,
#    'y_curve': 93},
#   {'id': 'c124',
#    'from': 'v13',
#    'to': 'v117',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 743,
#    'y_curve': 642},
#   {'id': 'c125',
#    'from': 'v13',
#    'to': 'v119',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 824,
#    'y_curve': 652},
#   {'id': 'c129',
#    'from': 'v39',
#    'to': 'v126',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c130',
#    'from': 'v39',
#    'to': 'v128',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c131',
#    'from': 'v118',
#    'to': 'v117',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 693,
#    'y_curve': 712},
#   {'id': 'c132',
#    'from': 'v118',
#    'to': 'v119',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 879,
#    'y_curve': 721},
#   {'id': 'c133',
#    'from': 'v127',
#    'to': 'v126',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1314,
#    'y_curve': 1361},
#   {'id': 'c134',
#    'from': 'v127',
#    'to': 'v128',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1513,
#    'y_curve': 1360}]}

# %%
model = read_vensim('frecuencia-de-mantenimiento-forrester.mdl')

# %%
model.doc
# Out:
#                                             Real Name  \
# 0                                   "Error/Faltante1"
# 1                                   "Error/Faltante2"
# 2                                   "Error/Faltante3"
# 3                                   "Error/Faltante4"
# 4                        Cantidad de fallas mecanicas
# 5                         Cantidad de malas maniobras
# 6      Cantidad de plazas apartadas por mantenimiento
# 7                         Cantidad de plazas ocupadas
# 8   Cantidad de plazas sin asignacion de mantenimi...
# 9                Cantidad de reparaciones preventivas
# 10  Cantidad de vehiculos destinados a mantenimien...
# 11  Cantidad de vehiculos destinados a mantenimien...
# 12             Cantidad de vehiculos en mantenimiento
# 13                 Cantidad de vehiculos en operacion
# 14  Cantidad de vehiculos que terminan el mantenim...
# 15  Cantidad promedio de malas maniobras por vehiculo
# 16                    Capacidad de atencion por plaza
# 17                               Demanda de operacion
# 18                          Demanda por mantenimiento
# 19                                      Discrepancia1
# 20                                      Discrepancia2
# 21                                      Discrepancia3
# 22                                      Discrepancia4
# 23                         Disponibilidad de la flota
# 24                         Disponibilidad de talleres
# 25                                         FINAL TIME
# 26                                       INITIAL TIME
# 27      Numero de veces que ocurre una falla mecanica
# 28                                          Objetivo1
# 29                                          Objetivo2
# 30                                          Objetivo3
# 31                                          Objetivo4
# 32  Proporcion de vehiculos que van a mantenimient...
# 33                     Reparacion de fallas mecanicas
# 34                                            SAVEPER
# 35                                          TIME STEP
# 36                                 Tasa de asignacion
# 37                           Tasa de fallas mecanicas
# 38                  Tasa de inoperatividad por fallas
# 39                       Tasa de liberacion de plazas
# 40             Tasa de reparacion de fallas mecanicas
# 41                   Tasa de reparaciones preventivas
# 42                        Tasa de retorno al deposito
# 43                   Tiempo promedio de mantenimiento
# 44                                               Time
# 45                                  Total de la flota
# 46                                    Total de plazas
# 47                       Vehiculos asignados a operar
# 48                    Vehiculos devueltos al deposito
# 49          Vehiculos operativos que mostraron fallas
# 50            Vehiculos que regresan de mantenimiento
# 51         Vehiculos que se retiran por mantenimiento
#
#                                               Py Name Subscripts  \
# 0                                      errorfaltante1       None
# 1                                      errorfaltante2       None
# 2                                      errorfaltante3       None
# 3                                      errorfaltante4       None
# 4                        cantidad_de_fallas_mecanicas       None
# 5                         cantidad_de_malas_maniobras       None
# 6      cantidad_de_plazas_apartadas_por_mantenimiento       None
# 7                         cantidad_de_plazas_ocupadas       None
# 8   cantidad_de_plazas_sin_asignacion_de_mantenimi...       None
# 9                cantidad_de_reparaciones_preventivas       None
# 10  cantidad_de_vehiculos_destinados_a_mantenimien...       None
# 11  cantidad_de_vehiculos_destinados_a_mantenimien...       None
# 12             cantidad_de_vehiculos_en_mantenimiento       None
# 13                 cantidad_de_vehiculos_en_operacion       None
# 14  cantidad_de_vehiculos_que_terminan_el_mantenim...       None
# 15  cantidad_promedio_de_malas_maniobras_por_vehiculo       None
# 16                    capacidad_de_atencion_por_plaza       None
# 17                               demanda_de_operacion       None
# 18                          demanda_por_mantenimiento       None
# 19                                      discrepancia1       None
# 20                                      discrepancia2       None
# 21                                      discrepancia3       None
# 22                                      discrepancia4       None
# 23                         disponibilidad_de_la_flota       None
# 24                         disponibilidad_de_talleres       None
# 25                                         final_time       None
# 26                                       initial_time       None
# 27      numero_de_veces_que_ocurre_una_falla_mecanica       None
# 28                                          objetivo1       None
# 29                                          objetivo2       None
# 30                                          objetivo3       None
# 31                                          objetivo4       None
# 32  proporcion_de_vehiculos_que_van_a_mantenimient...       None
# 33                     reparacion_de_fallas_mecanicas       None
# 34                                            saveper       None
# 35                                          time_step       None
# 36                                 tasa_de_asignacion       None
# 37                           tasa_de_fallas_mecanicas       None
# 38                  tasa_de_inoperatividad_por_fallas       None
# 39                       tasa_de_liberacion_de_plazas       None
# 40             tasa_de_reparacion_de_fallas_mecanicas       None
# 41                   tasa_de_reparaciones_preventivas       None
# 42                        tasa_de_retorno_al_deposito       None
# 43                   tiempo_promedio_de_mantenimiento       None
# 44                                               time       None
# 45                                  total_de_la_flota       None
# 46                                    total_de_plazas       None
# 47                       vehiculos_asignados_a_operar       None
# 48                    vehiculos_devueltos_al_deposito       None
# 49          vehiculos_operativos_que_mostraron_fallas       None
# 50            vehiculos_que_regresan_de_mantenimiento       None
# 51         vehiculos_que_se_retiran_por_mantenimiento       None
#
#                 Units      Limits       Type Subtype  \
# 0                None  (nan, nan)  Auxiliary  Normal
# 1                None  (nan, nan)  Auxiliary  Normal
# 2                None  (nan, nan)  Auxiliary  Normal
# 3                None  (nan, nan)  Auxiliary  Normal
# 4            Unidades  (nan, nan)   Stateful   Integ
# 5            Unidades  (nan, nan)  Auxiliary  Normal
# 6              Plazas  (nan, nan)  Auxiliary  Normal
# 7                None  (nan, nan)  Auxiliary  Normal
# 8              Plazas  (nan, nan)  Auxiliary  Normal
# 9            Unidades  (nan, nan)  Auxiliary  Normal
# 10          Vehiculos  (nan, nan)  Auxiliary  Normal
# 11          Vehiculos  (nan, nan)  Auxiliary  Normal
# 12          Vehiculos  (nan, nan)  Auxiliary  Normal
# 13          Vehiculos  (nan, nan)   Stateful   Integ
# 14          Vehiculos  (nan, nan)   Constant  Normal
# 15           Unidades  (nan, nan)   Constant  Normal
# 16             Plazas  (nan, nan)   Constant  Normal
# 17          Vehiculos  (nan, nan)   Constant  Normal
# 18             Plazas  (nan, nan)  Auxiliary  Normal
# 19               None  (nan, nan)  Auxiliary  Normal
# 20               None  (nan, nan)  Auxiliary  Normal
# 21               None  (nan, nan)  Auxiliary  Normal
# 22               None  (nan, nan)  Auxiliary  Normal
# 23          Vehiculos  (nan, nan)   Stateful   Integ
# 24             Plazas  (nan, nan)   Stateful   Integ
# 25               Year  (nan, nan)   Constant  Normal
# 26               Year  (nan, nan)   Constant  Normal
# 27           Unidades  (nan, nan)  Auxiliary  Normal
# 28               None  (nan, nan)   Constant  Normal
# 29               None  (nan, nan)   Constant  Normal
# 30               None  (nan, nan)   Constant  Normal
# 31               None  (nan, nan)   Constant  Normal
# 32               None  (nan, nan)   Constant  Normal
# 33           Unidades  (nan, nan)  Auxiliary  Normal
# 34               Year  (0.0, nan)  Auxiliary  Normal
# 35               Year  (0.0, nan)   Constant  Normal
# 36               None  (nan, nan)   Constant  Normal
# 37               None  (nan, nan)   Constant  Normal
# 38               None  (nan, nan)   Constant  Normal
# 39  Vehiculos/Semanas  (nan, nan)  Auxiliary  Normal
# 40               None  (nan, nan)   Constant  Normal
# 41               None  (nan, nan)   Constant  Normal
# 42               None  (nan, nan)   Constant  Normal
# 43            Semanas  (nan, nan)   Constant  Normal
# 44               None  (nan, nan)       None    None
# 45          Vehiculos  (nan, nan)   Constant  Normal
# 46             Plazas  (nan, nan)   Constant  Normal
# 47          Vehiculos  (nan, nan)  Auxiliary  Normal
# 48          Vehiculos  (nan, nan)  Auxiliary  Normal
# 49               None  (nan, nan)  Auxiliary  Normal
# 50          Vehiculos  (nan, nan)  Auxiliary  Normal
# 51          Vehiculos  (nan, nan)  Auxiliary  Normal
#
#                                        Comment
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# 5                                         None
# 6                                         None
# 7                                         None
# 8                                         None
# 9                                         None
# 10                                        None
# 11                                        None
# 12                                        None
# 13                                        None
# 14                                        None
# 15                                        None
# 16                                        None
# 17                                        None
# 18                                        None
# 19                                        None
# 20                                        None
# 21                                        None
# 22                                        None
# 23                                        None
# 24                                        None
# 25          The final time for the simulation.
# 26        The initial time for the simulation.
# 27                                        None
# 28                                        None
# 29                                        None
# 30                                        None
# 31                                        None
# 32                                        None
# 33                                        None
# 34  The frequency with which output is stored.
# 35           The time step for the simulation.
# 36                                        None
# 37                                        None
# 38                                        None
# 39                                        None
# 40                                        None
# 41                                        None
# 42                                        None
# 43                                        None
# 44                  Current time of the model.
# 45                                        None
# 46                                        None
# 47                                        None
# 48                                        None
# 49                                        None
# 50                                        None
# 51                                        None

# %%
data = model.run()

# %%
data
# Out:
#       FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  "Error/Faltante3"  \
# time
# 2025        2036          2025        1          1          25.000000
# 2026        2036          2025        1          1          28.000000
# 2027        2036          2025        1          1          38.400000
# 2028        2036          2025        1          1          43.420000
# 2029        2036          2025        1          1          37.886000
# 2030        2036          2025        1          1          31.989800
# 2031        2036          2025        1          1          32.358540
# 2032        2036          2025        1          1          34.393002
# 2033        2036          2025        1          1          36.034797
# 2034        2036          2025        1          1          37.455645
# 2035        2036          2025        1          1          35.917379
# 2036        2036          2025        1          1          35.087831
#
#       "Error/Faltante4"  Cantidad de plazas apartadas por mantenimiento  \
# time
# 2025              -20.0                                            35.0
# 2026               15.0                                            31.0
# 2027               11.0                                            15.0
# 2028               -5.0                                            11.0
# 2029               -9.0                                            20.0
# 2030                0.0                                            23.0
# 2031                3.0                                            23.0
# 2032                3.0                                            23.0
# 2033                3.0                                            20.0
# 2034                0.0                                            20.0
# 2035                0.0                                            20.0
# 2036                0.0                                            20.0
#
#       Objetivo1  Objetivo2  Cantidad de reparaciones preventivas  ...  \
# time                                                              ...
# 2025          9         15                                   112  ...
# 2026          9         15                                    96  ...
# 2027          9         15                                    48  ...
# 2028          9         15                                    32  ...
# 2029          9         15                                    64  ...
# 2030          9         15                                    72  ...
# 2031          9         15                                    72  ...
# 2032          9         15                                    72  ...
# 2033          9         15                                    64  ...
# 2034          9         15                                    64  ...
# 2035          9         15                                    64  ...
# 2036          9         15                                    64  ...
#
#       Tasa de liberacion de plazas  Tasa de retorno al deposito  \
# time
# 2025                           1.0                          0.1
# 2026                           1.0                          0.1
# 2027                           1.0                          0.1
# 2028                           1.0                          0.1
# 2029                           1.0                          0.1
# 2030                           1.0                          0.1
# 2031                           1.0                          0.1
# 2032                           1.0                          0.1
# 2033                           1.0                          0.1
# 2034                           1.0                          0.1
# 2035                           1.0                          0.1
# 2036                           1.0                          0.1
#
#       Tiempo promedio de mantenimiento  Total de la flota  Total de plazas  \
# time
# 2025                                 2                 50               40
# 2026                                 2                 50               40
# 2027                                 2                 50               40
# 2028                                 2                 50               40
# 2029                                 2                 50               40
# 2030                                 2                 50               40
# 2031                                 2                 50               40
# 2032                                 2                 50               40
# 2033                                 2                 50               40
# 2034                                 2                 50               40
# 2035                                 2                 50               40
# 2036                                 2                 50               40
#
#       Vehiculos asignados a operar  Vehiculos devueltos al deposito  \
# time
# 2025                      0.000000                         3.000000
# 2026                     -7.700000                         2.700000
# 2027                     -3.360000                         1.660000
# 2028                      6.692000                         1.158000
# 2029                      7.607600                         1.711400
# 2030                      1.932280                         2.301020
# 2031                      0.229684                         2.264146
# 2032                      0.418905                         2.060700
# 2033                      0.475672                         1.896520
# 2034                      3.292701                         1.754435
# 2035                      2.737810                         1.908262
# 2036                      2.921343                         1.991217
#
#       Vehiculos operativos que mostraron fallas  \
# time
# 2025                                          9
# 2026                                          8
# 2027                                          4
# 2028                                          3
# 2029                                          5
# 2030                                          6
# 2031                                          6
# 2032                                          6
# 2033                                          5
# 2034                                          5
# 2035                                          5
# 2036                                          5
#
#       Vehiculos que regresan de mantenimiento  \
# time
# 2025                                     25.0
# 2026                                     30.5
# 2027                                     27.0
# 2028                                     20.0
# 2029                                     19.5
# 2030                                     23.5
# 2031                                     24.5
# 2032                                     24.5
# 2033                                     24.5
# 2034                                     22.5
# 2035                                     23.0
# 2036                                     22.5
#
#       Vehiculos que se retiran por mantenimiento
# time
# 2025                                          36
# 2026                                          32
# 2027                                          16
# 2028                                          12
# 2029                                          20
# 2030                                          24
# 2031                                          24
# 2032                                          24
# 2033                                          20
# 2034                                          20
# 2035                                          20
# 2036                                          20
#
# [12 rows x 51 columns]

# %%
tasa_1 = model.components.tasa_de_inoperatividad_por_fallas()

# %%
tasa_1
# Out:
# 4

# %%
# !pip3 install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from plotly.express) (2.3.1)
# Collecting plotly>=4.1.0 (from plotly.express)
#   Downloading plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting statsmodels>=0.9.0 (from plotly.express)
#   Downloading statsmodels-0.14.5-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: scipy>=0.18 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from plotly.express) (1.15.2)
# Collecting patsy>=0.5 (from plotly.express)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.11 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from plotly.express) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\piter\appdata\roaming\python\python311\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from pandas>=0.20.0->plotly.express) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Collecting narwhals>=1.15.1 (from plotly>=4.1.0->plotly.express)
#   Downloading narwhals-1.47.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\piter\appdata\roaming\python\python311\site-packages (from plotly>=4.1.0->plotly.express) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\piter\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.16.0)
# Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.9 kB ? eta -:--:--
#    -------------------------------------- - 225.3/232.9 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 232.9/232.9 kB 4.8 MB/s eta 0:00:00
# Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/9.6 MB 14.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/9.6 MB 12.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.5/9.6 MB 11.6 MB/s eta 0:00:01
#    -------- ------------------------------- 2.0/9.6 MB 11.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/9.6 MB 11.5 MB/s eta 0:00:01
#    ------------ --------------------------- 3.0/9.6 MB 11.4 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.6 MB 11.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.6 MB 9.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.5/9.6 MB 8.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.6 MB 8.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.6 MB 8.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.1/9.6 MB 7.4 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.6 MB 7.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.6 MB 7.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.6 MB 6.4 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.6 MB 6.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.6 MB 5.8 MB/s eta 0:00:01
#    ------------------- -------------------- 4.6/9.6 MB 5.6 MB/s eta 0:00:01
#    ------------------- -------------------- 4.8/9.6 MB 5.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.6 MB 5.4 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.6 MB 5.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.4/9.6 MB 5.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.6/9.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.6 MB 5.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.1/9.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.6 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 6.7/9.6 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.6 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.7/9.6 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.3/9.6 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.6 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.1/9.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 5.4 MB/s eta 0:00:00
# Downloading statsmodels-0.14.5-cp311-cp311-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.6 MB 656.4 kB/s eta 0:00:15
#     --------------------------------------- 0.1/9.6 MB 1.2 MB/s eta 0:00:08
#     --------------------------------------- 0.2/9.6 MB 1.0 MB/s eta 0:00:10
#     --------------------------------------- 0.2/9.6 MB 807.1 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/9.6 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/9.6 MB 1.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/9.6 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.6 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.6 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.6 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/9.6 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.1/9.6 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.6 MB 2.0 MB/s eta 0:00:05
#    ------ --------------------------------- 1.5/9.6 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.7/9.6 MB 2.3 MB/s eta 0:00:04
#    ------- -------------------------------- 1.9/9.6 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.6 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.3/9.6 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.6 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.8/9.6 MB 2.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.6 MB 3.0 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.6 MB 3.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.6 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.8/9.6 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.8/9.6 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.6 MB 3.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.1/9.6 MB 3.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.1/9.6 MB 3.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.1/9.6 MB 3.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.3/9.6 MB 3.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.4/9.6 MB 3.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.6 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.9/9.6 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.6 MB 3.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.4/9.6 MB 3.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.7/9.6 MB 3.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.6 MB 3.4 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.6 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.6 MB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.6 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 7.4/9.6 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 7.7/9.6 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.6 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.0/9.6 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.6 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.6 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.6 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.6 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.8/9.6 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.0/9.6 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 3.8 MB/s eta 0:00:00
# Downloading narwhals-1.47.1-py3-none-any.whl (375 kB)
#    ---------------------------------------- 0.0/375.5 kB ? eta -:--:--
#    ----------------------- ---------------- 225.3/375.5 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 375.5/375.5 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: patsy, narwhals, plotly, statsmodels, plotly.express
# Successfully installed narwhals-1.47.1 patsy-1.0.1 plotly-6.2.0 plotly.express-0.4.1 statsmodels-0.14.5

# %%
import plotly_express as px

# %%
fig = px.line(data, y=["Disponibilidad de la flota","Vehiculos que regresan de mantenimiento","Vehiculos que se retiran por mantenimiento","Vehiculos asignados a operar"],title="Frecuencia de Mantenimiento")

# %%
fig.show()

# %%
data = model.run(params={"Tasa de inoperatividad por fallas": 1})

# %%
data
# Out:
#       FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  "Error/Faltante3"  \
# time
# 2025        2036          2025        1          1          25.000000
# 2026        2036          2025        1          1          28.000000
# 2027        2036          2025        1          1          19.500000
# 2028        2036          2025        1          1          13.390000
# 2029        2036          2025        1          1           9.053000
# 2030        2036          2025        1          1           6.548300
# 2031        2036          2025        1          1           4.713650
# 2032        2036          2025        1          1           3.538339
# 2033        2036          2025        1          1           2.973321
# 2034        2036          2025        1          1           2.612634
# 2035        2036          2025        1          1           1.982364
# 2036        2036          2025        1          1           1.673426
#
#       "Error/Faltante4"  Cantidad de plazas apartadas por mantenimiento  \
# time
# 2025              -20.0                                             8.0
# 2026              -12.0                                             7.0
# 2027              -13.0                                            10.0
# 2028              -10.0                                            11.0
# 2029               -9.0                                            12.0
# 2030               -8.0                                            13.0
# 2031               -7.0                                            15.0
# 2032               -5.0                                            15.0
# 2033               -5.0                                            15.0
# 2034               -5.0                                            15.0
# 2035               -5.0                                            15.0
# 2036               -5.0                                            15.0
#
#       Objetivo1  Objetivo2  Cantidad de reparaciones preventivas  ...  \
# time                                                              ...
# 2025          9         15                                    24  ...
# 2026          9         15                                    24  ...
# 2027          9         15                                    32  ...
# 2028          9         15                                    32  ...
# 2029          9         15                                    40  ...
# 2030          9         15                                    40  ...
# 2031          9         15                                    48  ...
# 2032          9         15                                    48  ...
# 2033          9         15                                    48  ...
# 2034          9         15                                    48  ...
# 2035          9         15                                    48  ...
# 2036          9         15                                    48  ...
#
#       Tasa de liberacion de plazas  Tasa de retorno al deposito  \
# time
# 2025                           1.0                          0.1
# 2026                           1.0                          0.1
# 2027                           1.0                          0.1
# 2028                           1.0                          0.1
# 2029                           1.0                          0.1
# 2030                           1.0                          0.1
# 2031                           1.0                          0.1
# 2032                           1.0                          0.1
# 2033                           1.0                          0.1
# 2034                           1.0                          0.1
# 2035                           1.0                          0.1
# 2036                           1.0                          0.1
#
#       Tiempo promedio de mantenimiento  Total de la flota  Total de plazas  \
# time
# 2025                                 2                 50               40
# 2026                                 2                 50               40
# 2027                                 2                 50               40
# 2028                                 2                 50               40
# 2029                                 2                 50               40
# 2030                                 2                 50               40
# 2031                                 2                 50               40
# 2032                                 2                 50               40
# 2033                                 2                 50               40
# 2034                                 2                 50               40
# 2035                                 2                 50               40
# 2036                                 2                 50               40
#
#       Vehiculos asignados a operar  Vehiculos devueltos al deposito  \
# time
# 2025                      0.000000                         3.000000
# 2026                     11.200000                         2.700000
# 2027                      9.660000                         3.550000
# 2028                      8.498000                         4.161000
# 2029                      7.099400                         4.594700
# 2030                      6.679820                         4.845170
# 2031                      6.203946                         5.028635
# 2032                      5.711184                         5.146166
# 2033                      5.563355                         5.202668
# 2034                      5.869007                         5.238737
# 2035                      5.610702                         5.301764
# 2036                      5.533211                         5.332657
#
#       Vehiculos operativos que mostraron fallas  \
# time
# 2025                                          9
# 2026                                          8
# 2027                                         10
# 2028                                         12
# 2029                                         13
# 2030                                         14
# 2031                                         15
# 2032                                         15
# 2033                                         15
# 2034                                         15
# 2035                                         15
# 2036                                         15
#
#       Vehiculos que regresan de mantenimiento  \
# time
# 2025                                     25.0
# 2026                                     17.0
# 2027                                     18.0
# 2028                                     18.5
# 2029                                     19.5
# 2030                                     20.0
# 2031                                     20.5
# 2032                                     20.5
# 2033                                     21.0
# 2034                                     20.5
# 2035                                     20.5
# 2036                                     21.0
#
#       Vehiculos que se retiran por mantenimiento
# time
# 2025                                           9
# 2026                                           8
# 2027                                          10
# 2028                                          12
# 2029                                          13
# 2030                                          14
# 2031                                          15
# 2032                                          15
# 2033                                          15
# 2034                                          15
# 2035                                          15
# 2036                                          15
#
# [12 rows x 51 columns]

# %%
fig = px.line(data, y=["Disponibilidad de la flota","Vehiculos que regresan de mantenimiento","Vehiculos que se retiran por mantenimiento","Vehiculos asignados a operar"],title="Frecuencia de Mantenimiento")
fig.show()
