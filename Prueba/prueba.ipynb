# %%
# !pip3 install pysd

# %%
import os
from pysd import read_vensim
import pandas as pd
import re

# %%
def parse_mdl_file(filepath):
    variables = []
    connections = []
    variable_ids = set()  # Para evitar duplicados

    with open(filepath, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    for line in lines:
        parts = line.strip().split(',')

        if not parts or len(parts) < 5:
            continue

        prefix = parts[0]

        if prefix in ['10', '11', '12']:  # Variable
            try:
                tipo = {
                    '10': 'auxiliary',
                    '11': 'stock',
                    '12': 'flow'
                }[prefix]

                vid = f"v{parts[1]}"
                name = parts[2].strip('"')

                if name == '0' or name.strip() == '':
                    continue  # Ignorar nombres inválidos

                if vid in variable_ids:
                    continue  # Ignorar duplicados

                x = int(parts[3])
                y = int(parts[4])

                variables.append({
                    "id": vid,
                    "name": name,
                    "type": tipo,
                    "x": x,
                    "y": y
                })

                variable_ids.add(vid)

            except Exception as e:
                print("[ERROR variable] Línea inválida:", line.strip(), "→", e)
                continue

        elif prefix == '1':  # Conexión
            try:
                cid = f"c{parts[1]}"
                from_id = f"v{parts[2]}"
                to_id = f"v{parts[3]}"

                text = line.strip()

                # Extraer color (primer patrón RGB)
                color_match = re.search(r"(\d+-\d+-\d+)", text)
                color = color_match.group(1) if color_match else None

                # Determinar polaridad según color
                if color == "0-0-255":
                    polarity = "positive"
                elif color == "255-0-0":
                    polarity = "negative"
                else:
                    polarity = "positive"

                # Extraer coordenadas de curva
                coord_match = re.search(r"\((\d+),(\d+)\)", text)
                if coord_match:
                    x_curve = int(coord_match.group(1))
                    y_curve = int(coord_match.group(2))
                else:
                    x_curve = None
                    y_curve = None

                connections.append({
                    "id": cid,
                    "from": from_id,
                    "to": to_id,
                    "color": color,
                    "polarity": polarity,
                    "x_curve": x_curve,
                    "y_curve": y_curve
                })

            except Exception as e:
                print("[ERROR conexión] Línea inválida:", line.strip(), "→", e)
                continue

    return {
        "name": os.path.basename(filepath),
        "variables": variables,
        "connections": connections
    }

# %%
parse_mdl_file("eficiencia-movilidad-causal.mdl")
# Out:
# {'name': 'eficiencia-movilidad-causal.mdl',
#  'variables': [{'id': 'v3',
#    'name': 'Congestión vehicular',
#    'type': 'auxiliary',
#    'x': 1301,
#    'y': 256},
#   {'id': 'v4',
#    'name': 'Eficiencia de movilidad',
#    'type': 'auxiliary',
#    'x': 1168,
#    'y': 467},
#   {'id': 'v6',
#    'name': 'Fluidez del tráfico',
#    'type': 'auxiliary',
#    'x': 880,
#    'y': 445},
#   {'id': 'v8',
#    'name': 'Uso del transporte público',
#    'type': 'auxiliary',
#    'x': 905,
#    'y': 167},
#   {'id': 'v9',
#    'name': 'Número de vehículos en circulación',
#    'type': 'auxiliary',
#    'x': 1040,
#    'y': 256},
#   {'id': 'v12',
#    'name': 'Calidad de transporte público',
#    'type': 'auxiliary',
#    'x': 733,
#    'y': 117},
#   {'id': 'v14',
#    'name': 'Extorsionesa a transportistas',
#    'type': 'auxiliary',
#    'x': 562,
#    'y': -8},
#   {'id': 'v15',
#    'name': 'Nivel de educación vial',
#    'type': 'auxiliary',
#    'x': 1565,
#    'y': -31},
#   {'id': 'v16',
#    'name': 'Total de Infracciones',
#    'type': 'auxiliary',
#    'x': 1230,
#    'y': 85},
#   {'id': 'v18',
#    'name': 'Cantidad de Transporte informal',
#    'type': 'auxiliary',
#    'x': 1541,
#    'y': 130},
#   {'id': 'v19',
#    'name': 'Paradas no autorizadas utilizadas por vehiculo',
#    'type': 'auxiliary',
#    'x': 1469,
#    'y': 208},
#   {'id': 'v23',
#    'name': 'Cruces de pistas indevidas por transeuntes',
#    'type': 'auxiliary',
#    'x': 1546,
#    'y': 337},
#   {'id': 'v26',
#    'name': 'Tasa de presión de pasajeros recibidas por conductores',
#    'type': 'auxiliary',
#    'x': 494,
#    'y': 587},
#   {'id': 'v28',
#    'name': 'Póliticas de regulación de transporte',
#    'type': 'auxiliary',
#    'x': 1407,
#    'y': 75},
#   {'id': 'v30',
#    'name': 'Uso de aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 1003,
#    'y': -25},
#   {'id': 'v33', 'name': 'Seguridad', 'type': 'auxiliary', 'x': 775, 'y': -124},
#   {'id': 'v36',
#    'name': 'Estres de transportistas',
#    'type': 'auxiliary',
#    'x': 567,
#    'y': 153},
#   {'id': 'v43',
#    'name': 'Calidad de infraestructura vial',
#    'type': 'auxiliary',
#    'x': 611,
#    'y': 379},
#   {'id': 'v46',
#    'name': 'Estratégicas de ejecución de obras',
#    'type': 'auxiliary',
#    'x': 730,
#    'y': 315},
#   {'id': 'v50',
#    'name': 'Tasa de seguridad',
#    'type': 'auxiliary',
#    'x': 678,
#    'y': -215},
#   {'id': 'v52',
#    'name': 'Tasa de infracciones',
#    'type': 'auxiliary',
#    'x': 1213,
#    'y': -71},
#   {'id': 'v54',
#    'name': 'Tasa de extorsiones a transportistas',
#    'type': 'auxiliary',
#    'x': 465,
#    'y': -123},
#   {'id': 'v56',
#    'name': 'Tasa de transeuntes que cruzan indevidamente',
#    'type': 'auxiliary',
#    'x': 1478,
#    'y': 473},
#   {'id': 'v58',
#    'name': 'Tasa de población que utiliza aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 1041,
#    'y': -157},
#   {'id': 'v60',
#    'name': 'Tasa de inversion de infraestructura',
#    'type': 'auxiliary',
#    'x': 649,
#    'y': 531},
#   {'id': 'v62',
#    'name': 'Tasa de transportes públicos en correcto estado',
#    'type': 'auxiliary',
#    'x': 799,
#    'y': 0},
#   {'id': 'v64',
#    'name': 'Tasa de vehiculos en circulación',
#    'type': 'auxiliary',
#    'x': 927,
#    'y': 338},
#   {'id': 'v66',
#    'name': 'Tasa de educacion vial de calidad',
#    'type': 'auxiliary',
#    'x': 1438,
#    'y': -120}],
#  'connections': [{'id': 'c5',
#    'from': 'v3',
#    'to': 'v4',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1227,
#    'y_curve': 457},
#   {'id': 'c7',
#    'from': 'v6',
#    'to': 'v4',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1016,
#    'y_curve': 513},
#   {'id': 'c10',
#    'from': 'v8',
#    'to': 'v9',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 932,
#    'y_curve': 235},
#   {'id': 'c11',
#    'from': 'v9',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1208,
#    'y_curve': 232},
#   {'id': 'c13',
#    'from': 'v12',
#    'to': 'v8',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 839,
#    'y_curve': 114},
#   {'id': 'c17',
#    'from': 'v16',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1281,
#    'y_curve': 126},
#   {'id': 'c20',
#    'from': 'v18',
#    'to': 'v19',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1528,
#    'y_curve': 217},
#   {'id': 'c21',
#    'from': 'v19',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1397,
#    'y_curve': 252},
#   {'id': 'c22',
#    'from': 'v15',
#    'to': 'v18',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1582,
#    'y_curve': 45},
#   {'id': 'c24',
#    'from': 'v15',
#    'to': 'v23',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1644,
#    'y_curve': 164},
#   {'id': 'c25',
#    'from': 'v23',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1400,
#    'y_curve': 317},
#   {'id': 'c27',
#    'from': 'v26',
#    'to': 'v19',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 944,
#    'y_curve': 665},
#   {'id': 'c29',
#    'from': 'v28',
#    'to': 'v18',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1496,
#    'y_curve': 68},
#   {'id': 'c31',
#    'from': 'v30',
#    'to': 'v8',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1008,
#    'y_curve': 76},
#   {'id': 'c32',
#    'from': 'v4',
#    'to': 'v30',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1120,
#    'y_curve': 218},
#   {'id': 'c34',
#    'from': 'v33',
#    'to': 'v30',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c35',
#    'from': 'v33',
#    'to': 'v14',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c37',
#    'from': 'v14',
#    'to': 'v36',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 519,
#    'y_curve': 65},
#   {'id': 'c38',
#    'from': 'v36',
#    'to': 'v12',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 640,
#    'y_curve': 105},
#   {'id': 'c39',
#    'from': 'v16',
#    'to': 'v36',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 897,
#    'y_curve': 231},
#   {'id': 'c40',
#    'from': 'v8',
#    'to': 'v30',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 903,
#    'y_curve': 64},
#   {'id': 'c41',
#    'from': 'v4',
#    'to': 'v3',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1202,
#    'y_curve': 340},
#   {'id': 'c42',
#    'from': 'v4',
#    'to': 'v6',
#    'color': '0-0-160',
#    'polarity': 'positive',
#    'x_curve': 1031,
#    'y_curve': 388},
#   {'id': 'c44',
#    'from': 'v43',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 757,
#    'y_curve': 463},
#   {'id': 'c45',
#    'from': 'v43',
#    'to': 'v36',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 548,
#    'y_curve': 254},
#   {'id': 'c47',
#    'from': 'v46',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 754,
#    'y_curve': 382},
#   {'id': 'c48',
#    'from': 'v8',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 847,
#    'y_curve': 294},
#   {'id': 'c49',
#    'from': 'v14',
#    'to': 'v33',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c51',
#    'from': 'v50',
#    'to': 'v33',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c53',
#    'from': 'v52',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1187,
#    'y_curve': 6},
#   {'id': 'c55',
#    'from': 'v54',
#    'to': 'v14',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c57',
#    'from': 'v56',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1579,
#    'y_curve': 448},
#   {'id': 'c59',
#    'from': 'v58',
#    'to': 'v30',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c61',
#    'from': 'v60',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 647,
#    'y_curve': 452},
#   {'id': 'c63',
#    'from': 'v62',
#    'to': 'v12',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 801,
#    'y_curve': 45},
#   {'id': 'c65',
#    'from': 'v64',
#    'to': 'v9',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1032,
#    'y_curve': 312},
#   {'id': 'c67',
#    'from': 'v66',
#    'to': 'v15',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c70',
#    'from': 'v26',
#    'to': 'v36',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 396,
#    'y_curve': 332}]}

# %%
parse_mdl_file("frecuencia-de-mantenimiento-forrester.mdl")
# Out:
# {'name': 'frecuencia-de-mantenimiento-forrester.mdl',
#  'variables': [{'id': 'v2',
#    'name': 'Disponibilidad de la flota',
#    'type': 'auxiliary',
#    'x': 1137,
#    'y': 415},
#   {'id': 'v3', 'name': '48', 'type': 'flow', 'x': 839, 'y': 408},
#   {'id': 'v7',
#    'name': 'Vehiculos que regresan de mantenimiento',
#    'type': 'auxiliary',
#    'x': 957,
#    'y': 446},
#   {'id': 'v8', 'name': '48', 'type': 'flow', 'x': 1423, 'y': 415},
#   {'id': 'v12',
#    'name': 'Vehiculos que se retiran por mantenimiento',
#    'type': 'auxiliary',
#    'x': 1314,
#    'y': 457},
#   {'id': 'v13',
#    'name': 'Cantidad de vehiculos en operacion',
#    'type': 'auxiliary',
#    'x': 1350,
#    'y': 654},
#   {'id': 'v17',
#    'name': 'Vehiculos asignados a operar',
#    'type': 'auxiliary',
#    'x': 1207,
#    'y': 577},
#   {'id': 'v18', 'name': '48', 'type': 'flow', 'x': 1710, 'y': 661},
#   {'id': 'v22',
#    'name': 'Vehiculos devueltos al deposito',
#    'type': 'auxiliary',
#    'x': 1587,
#    'y': 695},
#   {'id': 'v23',
#    'name': 'Cantidad de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2522,
#    'y': 457},
#   {'id': 'v24', 'name': '48', 'type': 'flow', 'x': 2115, 'y': 458},
#   {'id': 'v28',
#    'name': 'Numero de veces que ocurre una falla mecanica',
#    'type': 'auxiliary',
#    'x': 2286,
#    'y': 498},
#   {'id': 'v29', 'name': '48', 'type': 'flow', 'x': 2869, 'y': 453},
#   {'id': 'v33',
#    'name': 'Reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2718,
#    'y': 485},
#   {'id': 'v34', 'name': '48', 'type': 'flow', 'x': 2620, 'y': 754},
#   {'id': 'v38',
#    'name': 'Cantidad de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2676,
#    'y': 643},
#   {'id': 'v39',
#    'name': 'Disponibilidad de talleres',
#    'type': 'auxiliary',
#    'x': 1846,
#    'y': 1223},
#   {'id': 'v40', 'name': '48', 'type': 'flow', 'x': 1454, 'y': 1206},
#   {'id': 'v44',
#    'name': 'Cantidad de plazas sin asignacion de mantenimiento',
#    'type': 'auxiliary',
#    'x': 1627,
#    'y': 1242},
#   {'id': 'v45', 'name': '48', 'type': 'flow', 'x': 2179, 'y': 1222},
#   {'id': 'v49',
#    'name': 'Cantidad de plazas apartadas por mantenimiento',
#    'type': 'auxiliary',
#    'x': 2046,
#    'y': 1260},
#   {'id': 'v50',
#    'name': 'Tiempo promedio de mantenimiento',
#    'type': 'auxiliary',
#    'x': 883,
#    'y': 803},
#   {'id': 'v51',
#    'name': 'Tasa de liberacion de plazas',
#    'type': 'auxiliary',
#    'x': 1248,
#    'y': 877},
#   {'id': 'v52',
#    'name': 'Cantidad de vehiculos que terminan el mantenimiento por semana',
#    'type': 'auxiliary',
#    'x': 1003,
#    'y': 1039},
#   {'id': 'v53',
#    'name': 'Total de plazas',
#    'type': 'auxiliary',
#    'x': 1442,
#    'y': 1300},
#   {'id': 'v54',
#    'name': 'Cantidad de plazas ocupadas',
#    'type': 'auxiliary',
#    'x': 1462,
#    'y': 1391},
#   {'id': 'v55',
#    'name': 'Capacidad de atencion por plaza',
#    'type': 'auxiliary',
#    'x': 2291,
#    'y': 1303},
#   {'id': 'v56',
#    'name': 'Demanda por mantenimiento',
#    'type': 'auxiliary',
#    'x': 2321,
#    'y': 1090},
#   {'id': 'v57',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento preventivo',
#    'type': 'auxiliary',
#    'x': 2635,
#    'y': 892},
#   {'id': 'v58',
#    'name': 'Proporcion de vehiculos que van a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 2112,
#    'y': 855},
#   {'id': 'v59',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 2381,
#    'y': 577},
#   {'id': 'v60',
#    'name': 'Cantidad promedio de malas maniobras por vehiculo',
#    'type': 'auxiliary',
#    'x': 1923,
#    'y': 431},
#   {'id': 'v61',
#    'name': 'Cantidad de malas maniobras',
#    'type': 'auxiliary',
#    'x': 1669,
#    'y': 406},
#   {'id': 'v62',
#    'name': 'Tasa de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 1538,
#    'y': 245},
#   {'id': 'v63',
#    'name': 'Vehiculos operativos que mostraron fallas',
#    'type': 'auxiliary',
#    'x': 1451,
#    'y': 339},
#   {'id': 'v64',
#    'name': 'Tasa de inoperatividad por fallas',
#    'type': 'auxiliary',
#    'x': 1338,
#    'y': 178},
#   {'id': 'v65',
#    'name': 'Total de la flota',
#    'type': 'auxiliary',
#    'x': 616,
#    'y': 466},
#   {'id': 'v66',
#    'name': 'Cantidad de vehiculos en mantenimiento',
#    'type': 'auxiliary',
#    'x': 776,
#    'y': 318},
#   {'id': 'v67',
#    'name': 'Tasa de asignacion',
#    'type': 'auxiliary',
#    'x': 993,
#    'y': 587},
#   {'id': 'v68',
#    'name': 'Tasa de retorno al deposito',
#    'type': 'auxiliary',
#    'x': 1611,
#    'y': 823},
#   {'id': 'v99',
#    'name': 'Demanda de operacion',
#    'type': 'auxiliary',
#    'x': 1029,
#    'y': 721},
#   {'id': 'v103',
#    'name': 'Tasa de reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2876,
#    'y': 339},
#   {'id': 'v105',
#    'name': 'Tasa de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2781,
#    'y': 748},
#   {'id': 'v107',
#    'name': 'Objetivo2',
#    'type': 'auxiliary',
#    'x': 2364,
#    'y': 287},
#   {'id': 'v108',
#    'name': 'Discrepancia2',
#    'type': 'auxiliary',
#    'x': 2479,
#    'y': 336},
#   {'id': 'v109',
#    'name': 'Error/Faltante2',
#    'type': 'auxiliary',
#    'x': 2285,
#    'y': 363},
#   {'id': 'v114',
#    'name': 'Discrepancia1',
#    'type': 'auxiliary',
#    'x': 1218,
#    'y': 241},
#   {'id': 'v115',
#    'name': 'Objetivo1',
#    'type': 'auxiliary',
#    'x': 1089,
#    'y': 145},
#   {'id': 'v116',
#    'name': 'Error/Faltante1',
#    'type': 'auxiliary',
#    'x': 983,
#    'y': 263},
#   {'id': 'v117',
#    'name': 'Discrepancia3',
#    'type': 'auxiliary',
#    'x': 1171,
#    'y': 716},
#   {'id': 'v118',
#    'name': 'Objetivo3',
#    'type': 'auxiliary',
#    'x': 1281,
#    'y': 808},
#   {'id': 'v119',
#    'name': 'Error/Faltante3',
#    'type': 'auxiliary',
#    'x': 1428,
#    'y': 735},
#   {'id': 'v126',
#    'name': 'Discrepancia4',
#    'type': 'auxiliary',
#    'x': 1839,
#    'y': 1358},
#   {'id': 'v127',
#    'name': 'Objetivo4',
#    'type': 'auxiliary',
#    'x': 1918,
#    'y': 1423},
#   {'id': 'v128',
#    'name': 'Error/Faltante4',
#    'type': 'auxiliary',
#    'x': 2052,
#    'y': 1373}],
#  'connections': [{'id': 'c4',
#    'from': 'v6',
#    'to': 'v3',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 900,
#    'y_curve': 408},
#   {'id': 'c5',
#    'from': 'v6',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1017,
#    'y_curve': 408},
#   {'id': 'c9',
#    'from': 'v11',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1255,
#    'y_curve': 415},
#   {'id': 'c10',
#    'from': 'v11',
#    'to': 'v8',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1366,
#    'y_curve': 415},
#   {'id': 'c14',
#    'from': 'v16',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1125,
#    'y_curve': 506},
#   {'id': 'c15',
#    'from': 'v16',
#    'to': 'v13',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1125,
#    'y_curve': 654},
#   {'id': 'c19',
#    'from': 'v21',
#    'to': 'v13',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1510,
#    'y_curve': 661},
#   {'id': 'c20',
#    'from': 'v21',
#    'to': 'v18',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1646,
#    'y_curve': 661},
#   {'id': 'c25',
#    'from': 'v27',
#    'to': 'v24',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2202,
#    'y_curve': 458},
#   {'id': 'c26',
#    'from': 'v27',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2369,
#    'y_curve': 458},
#   {'id': 'c30',
#    'from': 'v32',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2655,
#    'y_curve': 453},
#   {'id': 'c31',
#    'from': 'v32',
#    'to': 'v29',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2791,
#    'y_curve': 453},
#   {'id': 'c35',
#    'from': 'v37',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2546,
#    'y_curve': 560},
#   {'id': 'c36',
#    'from': 'v37',
#    'to': 'v34',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2546,
#    'y_curve': 754},
#   {'id': 'c41',
#    'from': 'v43',
#    'to': 'v40',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1556,
#    'y_curve': 1206},
#   {'id': 'c42',
#    'from': 'v43',
#    'to': 'v39',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1706,
#    'y_curve': 1206},
#   {'id': 'c46',
#    'from': 'v48',
#    'to': 'v39',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1976,
#    'y_curve': 1222},
#   {'id': 'c47',
#    'from': 'v48',
#    'to': 'v45',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2110,
#    'y_curve': 1222},
#   {'id': 'c69',
#    'from': 'v2',
#    'to': 'v66',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 983,
#    'y_curve': 295},
#   {'id': 'c70',
#    'from': 'v66',
#    'to': 'v6',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 917,
#    'y_curve': 356},
#   {'id': 'c71',
#    'from': 'v65',
#    'to': 'v66',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 727,
#    'y_curve': 436},
#   {'id': 'c72',
#    'from': 'v50',
#    'to': 'v7',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c73',
#    'from': 'v50',
#    'to': 'v51',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c74',
#    'from': 'v52',
#    'to': 'v51',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1202,
#    'y_curve': 987},
#   {'id': 'c75',
#    'from': 'v39',
#    'to': 'v54',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1721,
#    'y_curve': 1376},
#   {'id': 'c76',
#    'from': 'v55',
#    'to': 'v49',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c77',
#    'from': 'v56',
#    'to': 'v48',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2177,
#    'y_curve': 1249},
#   {'id': 'c78',
#    'from': 'v57',
#    'to': 'v56',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2524,
#    'y_curve': 1024},
#   {'id': 'c79',
#    'from': 'v57',
#    'to': 'v37',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2634,
#    'y_curve': 782},
#   {'id': 'c80',
#    'from': 'v58',
#    'to': 'v57',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c81',
#    'from': 'v59',
#    'to': 'v56',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c82',
#    'from': 'v58',
#    'to': 'v59',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c83',
#    'from': 'v59',
#    'to': 'v32',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2538,
#    'y_curve': 576},
#   {'id': 'c84',
#    'from': 'v62',
#    'to': 'v27',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2067,
#    'y_curve': 196},
#   {'id': 'c85',
#    'from': 'v61',
#    'to': 'v28',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2077,
#    'y_curve': 280},
#   {'id': 'c86',
#    'from': 'v60',
#    'to': 'v61',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1792,
#    'y_curve': 469},
#   {'id': 'c87',
#    'from': 'v13',
#    'to': 'v61',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c88',
#    'from': 'v13',
#    'to': 'v21',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1508,
#    'y_curve': 628},
#   {'id': 'c89',
#    'from': 'v68',
#    'to': 'v22',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1626,
#    'y_curve': 722},
#   {'id': 'c90',
#    'from': 'v13',
#    'to': 'v63',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1462,
#    'y_curve': 509},
#   {'id': 'c91',
#    'from': 'v62',
#    'to': 'v63',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1471,
#    'y_curve': 244},
#   {'id': 'c92',
#    'from': 'v64',
#    'to': 'v11',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c93',
#    'from': 'v63',
#    'to': 'v11',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c94',
#    'from': 'v12',
#    'to': 'v59',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c95',
#    'from': 'v12',
#    'to': 'v57',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c96',
#    'from': 'v2',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1180,
#    'y_curve': 494},
#   {'id': 'c97',
#    'from': 'v67',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1060,
#    'y_curve': 543},
#   {'id': 'c98',
#    'from': 'v53',
#    'to': 'v54',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1477,
#    'y_curve': 1337},
#   {'id': 'c100',
#    'from': 'v99',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c101',
#    'from': 'v54',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1579,
#    'y_curve': 1350},
#   {'id': 'c102',
#    'from': 'v51',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c104',
#    'from': 'v103',
#    'to': 'v32',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2742,
#    'y_curve': 321},
#   {'id': 'c106',
#    'from': 'v105',
#    'to': 'v37',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c110',
#    'from': 'v107',
#    'to': 'v108',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2447,
#    'y_curve': 293},
#   {'id': 'c111',
#    'from': 'v107',
#    'to': 'v109',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2293,
#    'y_curve': 316},
#   {'id': 'c112',
#    'from': 'v23',
#    'to': 'v109',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2413,
#    'y_curve': 394},
#   {'id': 'c113',
#    'from': 'v23',
#    'to': 'v108',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c120',
#    'from': 'v2',
#    'to': 'v114',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c121',
#    'from': 'v2',
#    'to': 'v116',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1102,
#    'y_curve': 307},
#   {'id': 'c122',
#    'from': 'v115',
#    'to': 'v114',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1181,
#    'y_curve': 165},
#   {'id': 'c123',
#    'from': 'v115',
#    'to': 'v116',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1005,
#    'y_curve': 165},
#   {'id': 'c124',
#    'from': 'v13',
#    'to': 'v117',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1243,
#    'y_curve': 714},
#   {'id': 'c125',
#    'from': 'v13',
#    'to': 'v119',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1324,
#    'y_curve': 724},
#   {'id': 'c129',
#    'from': 'v39',
#    'to': 'v126',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c130',
#    'from': 'v39',
#    'to': 'v128',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c131',
#    'from': 'v118',
#    'to': 'v117',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1193,
#    'y_curve': 784},
#   {'id': 'c132',
#    'from': 'v118',
#    'to': 'v119',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1379,
#    'y_curve': 793},
#   {'id': 'c133',
#    'from': 'v127',
#    'to': 'v126',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1814,
#    'y_curve': 1433},
#   {'id': 'c134',
#    'from': 'v127',
#    'to': 'v128',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2013,
#    'y_curve': 1432}]}

# %%
model = read_vensim('frecuencia-de-mantenimiento-forrester.mdl')

# %%
data = model.run()

# %%
data
# Out:
#       FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  "Error/Faltante3"  \
# time
# 2025        2036          2025        1          1          25.000000
# 2026        2036          2025        1          1          28.000000
# 2027        2036          2025        1          1          19.374000
# 2028        2036          2025        1          1          13.476800
# 2029        2036          2025        1          1           9.051180
# 2030        2036          2025        1          1           6.354680
# 2031        2036          2025        1          1           4.299797
# 2032        2036          2025        1          1           2.897993
# 2033        2036          2025        1          1           2.456647
# 2034        2036          2025        1          1           1.955518
# 2035        2036          2025        1          1           1.473327
# 2036        2036          2025        1          1           1.030002
#
#       "Error/Faltante4"  Cantidad de plazas apartadas por mantenimiento  \
# time
# 2025              -20.0                                             8.0
# 2026              -12.0                                             7.0
# 2027              -13.0                                             8.0
# 2028              -12.0                                            11.0
# 2029               -9.0                                            12.0
# 2030               -8.0                                            13.0
# 2031               -7.0                                            13.0
# 2032               -7.0                                            13.0
# 2033               -7.0                                            13.0
# 2034               -7.0                                            13.0
# 2035               -7.0                                            15.0
# 2036               -5.0                                            15.0
#
#       Objetivo1  Objetivo2  Cantidad de reparaciones preventivas  ...  \
# time                                                              ...
# 2025          9         15                                    24  ...
# 2026          9         15                                    24  ...
# 2027          9         15                                    24  ...
# 2028          9         15                                    32  ...
# 2029          9         15                                    40  ...
# 2030          9         15                                    40  ...
# 2031          9         15                                    40  ...
# 2032          9         15                                    40  ...
# 2033          9         15                                    40  ...
# 2034          9         15                                    40  ...
# 2035          9         15                                    48  ...
# 2036          9         15                                    48  ...
#
#       Tasa de liberacion de plazas  Tasa de retorno al deposito  \
# time
# 2025                           1.0                          0.1
# 2026                           1.0                          0.1
# 2027                           1.0                          0.1
# 2028                           1.0                          0.1
# 2029                           1.0                          0.1
# 2030                           1.0                          0.1
# 2031                           1.0                          0.1
# 2032                           1.0                          0.1
# 2033                           1.0                          0.1
# 2034                           1.0                          0.1
# 2035                           1.0                          0.1
# 2036                           1.0                          0.1
#
#       Tiempo promedio de mantenimiento  Total de la flota  Total de plazas  \
# time
# 2025                                 2                 50               40
# 2026                                 2                 50               40
# 2027                                 2                 50               40
# 2028                                 2                 50               40
# 2029                                 2                 50               40
# 2030                                 2                 50               40
# 2031                                 2                 50               40
# 2032                                 2                 50               40
# 2033                                 2                 50               40
# 2034                                 2                 50               40
# 2035                                 2                 50               40
# 2036                                 2                 50               40
#
#       Vehiculos asignados a operar  Vehiculos devueltos al deposito  \
# time
# 2025                      0.000000                         3.000000
# 2026                     11.326000                         2.700000
# 2027                      9.459800                         3.562600
# 2028                      8.577940                         4.152320
# 2029                      7.291382                         4.594882
# 2030                      6.919415                         4.864532
# 2031                      6.471824                         5.070020
# 2032                      5.651547                         5.210201
# 2033                      5.755464                         5.254335
# 2034                      5.786639                         5.304448
# 2035                      5.795992                         5.352667
# 2036                      5.112798                         5.397000
#
#       Vehiculos operativos que mostraron fallas  \
# time
# 2025                                          9
# 2026                                          8
# 2027                                         10
# 2028                                         12
# 2029                                         13
# 2030                                         14
# 2031                                         15
# 2032                                         15
# 2033                                         15
# 2034                                         15
# 2035                                         16
# 2036                                         16
#
#       Vehiculos que regresan de mantenimiento  \
# time
# 2025                                     25.0
# 2026                                     16.5
# 2027                                     18.0
# 2028                                     18.5
# 2029                                     19.5
# 2030                                     20.0
# 2031                                     20.0
# 2032                                     20.5
# 2033                                     20.5
# 2034                                     20.5
# 2035                                     20.5
# 2036                                     21.0
#
#       Vehiculos que se retiran por mantenimiento
# time
# 2025                                        8.82
# 2026                                        7.84
# 2027                                        9.80
# 2028                                       11.76
# 2029                                       12.74
# 2030                                       13.72
# 2031                                       14.70
# 2032                                       14.70
# 2033                                       14.70
# 2034                                       14.70
# 2035                                       15.68
# 2036                                       15.68
#
# [12 rows x 51 columns]
