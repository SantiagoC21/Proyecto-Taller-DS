# %%
# !pip3 install pysd

# %%
import os
from pysd import read_vensim
import pandas as pd
import re

# %%
def parse_mdl_file(filepath):
    variables = []
    connections = []
    variable_ids = set()  # Para evitar duplicados

    with open(filepath, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    for line in lines:
        parts = line.strip().split(',')

        if not parts or len(parts) < 5:
            continue

        prefix = parts[0]

        if prefix in ['10', '11', '12']:  # Variable
            try:
                tipo = {
                    '10': 'auxiliary',
                    '11': 'stock',
                    '12': 'flow'
                }[prefix]

                vid = f"v{parts[1]}"
                name = parts[2].strip('"')

                if name == '0' or name.strip() == '':
                    continue  # Ignorar nombres inválidos

                if vid in variable_ids:
                    continue  # Ignorar duplicados

                x = int(parts[3])
                y = int(parts[4])

                variables.append({
                    "id": vid,
                    "name": name,
                    "type": tipo,
                    "x": x,
                    "y": y
                })

                variable_ids.add(vid)

            except Exception as e:
                print("[ERROR variable] Línea inválida:", line.strip(), "→", e)
                continue

        elif prefix == '1':  # Conexión
            try:
                cid = f"c{parts[1]}"
                from_id = f"v{parts[2]}"
                to_id = f"v{parts[3]}"

                text = line.strip()

                # Extraer color (primer patrón RGB)
                color_match = re.search(r"(\d+-\d+-\d+)", text)
                color = color_match.group(1) if color_match else None

                # Determinar polaridad según color
                if color == "0-0-255":
                    polarity = "positive"
                elif color == "255-0-0":
                    polarity = "negative"
                else:
                    polarity = "positive"

                # Extraer coordenadas de curva
                coord_match = re.search(r"\((\d+),(\d+)\)", text)
                if coord_match:
                    x_curve = int(coord_match.group(1))
                    y_curve = int(coord_match.group(2))
                else:
                    x_curve = None
                    y_curve = None

                connections.append({
                    "id": cid,
                    "from": from_id,
                    "to": to_id,
                    "color": color,
                    "polarity": polarity,
                    "x_curve": x_curve,
                    "y_curve": y_curve
                })

            except Exception as e:
                print("[ERROR conexión] Línea inválida:", line.strip(), "→", e)
                continue

    return {
        "name": os.path.basename(filepath),
        "variables": variables,
        "connections": connections
    }

# %%
parse_mdl_file("eficiencia-movilidad-causal.mdl")
# Out:
# {'name': 'eficiencia-movilidad-causal.mdl',
#  'variables': [{'id': 'v3',
#    'name': 'Congestión vehicular',
#    'type': 'auxiliary',
#    'x': 1301,
#    'y': 256},
#   {'id': 'v4',
#    'name': 'Eficiencia de movilidad',
#    'type': 'auxiliary',
#    'x': 1168,
#    'y': 467},
#   {'id': 'v6',
#    'name': 'Fluidez del tráfico',
#    'type': 'auxiliary',
#    'x': 880,
#    'y': 445},
#   {'id': 'v8',
#    'name': 'Uso del transporte público',
#    'type': 'auxiliary',
#    'x': 905,
#    'y': 167},
#   {'id': 'v9',
#    'name': 'Número de vehículos en circulación',
#    'type': 'auxiliary',
#    'x': 1040,
#    'y': 256},
#   {'id': 'v12',
#    'name': 'Calidad de transporte público',
#    'type': 'auxiliary',
#    'x': 733,
#    'y': 117},
#   {'id': 'v14',
#    'name': 'Extorsionesa a transportistas',
#    'type': 'auxiliary',
#    'x': 562,
#    'y': -8},
#   {'id': 'v15',
#    'name': 'Nivel de educación vial',
#    'type': 'auxiliary',
#    'x': 1565,
#    'y': -31},
#   {'id': 'v16',
#    'name': 'Total de Infracciones',
#    'type': 'auxiliary',
#    'x': 1230,
#    'y': 85},
#   {'id': 'v18',
#    'name': 'Cantidad de Transporte informal',
#    'type': 'auxiliary',
#    'x': 1541,
#    'y': 130},
#   {'id': 'v19',
#    'name': 'Paradas no autorizadas utilizadas por vehiculo',
#    'type': 'auxiliary',
#    'x': 1469,
#    'y': 208},
#   {'id': 'v23',
#    'name': 'Cruces de pistas indevidas por transeuntes',
#    'type': 'auxiliary',
#    'x': 1546,
#    'y': 337},
#   {'id': 'v26',
#    'name': 'Tasa de presión de pasajeros recibidas por conductores',
#    'type': 'auxiliary',
#    'x': 494,
#    'y': 587},
#   {'id': 'v28',
#    'name': 'Póliticas de regulación de transporte',
#    'type': 'auxiliary',
#    'x': 1407,
#    'y': 75},
#   {'id': 'v30',
#    'name': 'Uso de aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 1003,
#    'y': -25},
#   {'id': 'v33', 'name': 'Seguridad', 'type': 'auxiliary', 'x': 775, 'y': -124},
#   {'id': 'v36',
#    'name': 'Estres de transportistas',
#    'type': 'auxiliary',
#    'x': 567,
#    'y': 153},
#   {'id': 'v43',
#    'name': 'Calidad de infraestructura vial',
#    'type': 'auxiliary',
#    'x': 611,
#    'y': 379},
#   {'id': 'v46',
#    'name': 'Estratégicas de ejecución de obras',
#    'type': 'auxiliary',
#    'x': 730,
#    'y': 315},
#   {'id': 'v50',
#    'name': 'Tasa de seguridad',
#    'type': 'auxiliary',
#    'x': 678,
#    'y': -215},
#   {'id': 'v52',
#    'name': 'Tasa de infracciones',
#    'type': 'auxiliary',
#    'x': 1213,
#    'y': -71},
#   {'id': 'v54',
#    'name': 'Tasa de extorsiones a transportistas',
#    'type': 'auxiliary',
#    'x': 465,
#    'y': -123},
#   {'id': 'v56',
#    'name': 'Tasa de transeuntes que cruzan indevidamente',
#    'type': 'auxiliary',
#    'x': 1478,
#    'y': 473},
#   {'id': 'v58',
#    'name': 'Tasa de población que utiliza aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 1041,
#    'y': -157},
#   {'id': 'v60',
#    'name': 'Tasa de inversion de infraestructura',
#    'type': 'auxiliary',
#    'x': 649,
#    'y': 531},
#   {'id': 'v62',
#    'name': 'Tasa de transportes públicos en correcto estado',
#    'type': 'auxiliary',
#    'x': 799,
#    'y': 0},
#   {'id': 'v64',
#    'name': 'Tasa de vehiculos en circulación',
#    'type': 'auxiliary',
#    'x': 927,
#    'y': 338},
#   {'id': 'v66',
#    'name': 'Tasa de educacion vial de calidad',
#    'type': 'auxiliary',
#    'x': 1438,
#    'y': -120}],
#  'connections': [{'id': 'c5',
#    'from': 'v3',
#    'to': 'v4',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1227,
#    'y_curve': 457},
#   {'id': 'c7',
#    'from': 'v6',
#    'to': 'v4',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1016,
#    'y_curve': 513},
#   {'id': 'c10',
#    'from': 'v8',
#    'to': 'v9',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 932,
#    'y_curve': 235},
#   {'id': 'c11',
#    'from': 'v9',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1208,
#    'y_curve': 232},
#   {'id': 'c13',
#    'from': 'v12',
#    'to': 'v8',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 839,
#    'y_curve': 114},
#   {'id': 'c17',
#    'from': 'v16',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1281,
#    'y_curve': 126},
#   {'id': 'c20',
#    'from': 'v18',
#    'to': 'v19',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1528,
#    'y_curve': 217},
#   {'id': 'c21',
#    'from': 'v19',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1397,
#    'y_curve': 252},
#   {'id': 'c22',
#    'from': 'v15',
#    'to': 'v18',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1582,
#    'y_curve': 45},
#   {'id': 'c24',
#    'from': 'v15',
#    'to': 'v23',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1644,
#    'y_curve': 164},
#   {'id': 'c25',
#    'from': 'v23',
#    'to': 'v3',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1400,
#    'y_curve': 317},
#   {'id': 'c27',
#    'from': 'v26',
#    'to': 'v19',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 944,
#    'y_curve': 665},
#   {'id': 'c29',
#    'from': 'v28',
#    'to': 'v18',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1496,
#    'y_curve': 68},
#   {'id': 'c31',
#    'from': 'v30',
#    'to': 'v8',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1008,
#    'y_curve': 76},
#   {'id': 'c32',
#    'from': 'v4',
#    'to': 'v30',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 1120,
#    'y_curve': 218},
#   {'id': 'c34',
#    'from': 'v33',
#    'to': 'v30',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c35',
#    'from': 'v33',
#    'to': 'v14',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c37',
#    'from': 'v14',
#    'to': 'v36',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 519,
#    'y_curve': 65},
#   {'id': 'c38',
#    'from': 'v36',
#    'to': 'v12',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 640,
#    'y_curve': 105},
#   {'id': 'c39',
#    'from': 'v16',
#    'to': 'v36',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 897,
#    'y_curve': 231},
#   {'id': 'c40',
#    'from': 'v8',
#    'to': 'v30',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 903,
#    'y_curve': 64},
#   {'id': 'c41',
#    'from': 'v4',
#    'to': 'v3',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 1202,
#    'y_curve': 340},
#   {'id': 'c42',
#    'from': 'v4',
#    'to': 'v6',
#    'color': '0-0-160',
#    'polarity': 'positive',
#    'x_curve': 1031,
#    'y_curve': 388},
#   {'id': 'c44',
#    'from': 'v43',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 757,
#    'y_curve': 463},
#   {'id': 'c45',
#    'from': 'v43',
#    'to': 'v36',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': 548,
#    'y_curve': 254},
#   {'id': 'c47',
#    'from': 'v46',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 754,
#    'y_curve': 382},
#   {'id': 'c48',
#    'from': 'v8',
#    'to': 'v6',
#    'color': '0-0-0',
#    'polarity': 'positive',
#    'x_curve': 847,
#    'y_curve': 294},
#   {'id': 'c49',
#    'from': 'v14',
#    'to': 'v33',
#    'color': '255-0-0',
#    'polarity': 'negative',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c51',
#    'from': 'v50',
#    'to': 'v33',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c53',
#    'from': 'v52',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1187,
#    'y_curve': 6},
#   {'id': 'c55',
#    'from': 'v54',
#    'to': 'v14',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c57',
#    'from': 'v56',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1579,
#    'y_curve': 448},
#   {'id': 'c59',
#    'from': 'v58',
#    'to': 'v30',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c61',
#    'from': 'v60',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 647,
#    'y_curve': 452},
#   {'id': 'c63',
#    'from': 'v62',
#    'to': 'v12',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 801,
#    'y_curve': 45},
#   {'id': 'c65',
#    'from': 'v64',
#    'to': 'v9',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1032,
#    'y_curve': 312},
#   {'id': 'c67',
#    'from': 'v66',
#    'to': 'v15',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': None,
#    'y_curve': None},
#   {'id': 'c70',
#    'from': 'v26',
#    'to': 'v36',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 396,
#    'y_curve': 332}]}

# %%
parse_mdl_file("frecuencia-de-mantenimiento-forrester.mdl")
# Out:
# {'name': 'frecuencia-de-mantenimiento-forrester.mdl',
#  'variables': [{'id': 'v2',
#    'name': 'Disponibilidad de la flota',
#    'type': 'auxiliary',
#    'x': 637,
#    'y': 343},
#   {'id': 'v3', 'name': '48', 'type': 'flow', 'x': 339, 'y': 336},
#   {'id': 'v7',
#    'name': 'Vehiculos que regresan de mantenimiento',
#    'type': 'auxiliary',
#    'x': 457,
#    'y': 374},
#   {'id': 'v8', 'name': '48', 'type': 'flow', 'x': 923, 'y': 343},
#   {'id': 'v12',
#    'name': 'Vehiculos que se retiran por mantenimiento',
#    'type': 'auxiliary',
#    'x': 814,
#    'y': 385},
#   {'id': 'v13',
#    'name': 'Cantidad de vehiculos en operacion',
#    'type': 'auxiliary',
#    'x': 850,
#    'y': 582},
#   {'id': 'v17',
#    'name': 'Vehiculos asignados a operar',
#    'type': 'auxiliary',
#    'x': 707,
#    'y': 505},
#   {'id': 'v18', 'name': '48', 'type': 'flow', 'x': 1210, 'y': 589},
#   {'id': 'v22',
#    'name': 'Vehiculos devueltos al deposito',
#    'type': 'auxiliary',
#    'x': 1087,
#    'y': 623},
#   {'id': 'v23',
#    'name': 'Cantidad de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2022,
#    'y': 385},
#   {'id': 'v24', 'name': '48', 'type': 'flow', 'x': 1615, 'y': 386},
#   {'id': 'v28',
#    'name': 'Numero de veces que ocurre una falla mecanica',
#    'type': 'auxiliary',
#    'x': 1786,
#    'y': 426},
#   {'id': 'v29', 'name': '48', 'type': 'flow', 'x': 2369, 'y': 381},
#   {'id': 'v33',
#    'name': 'Reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2218,
#    'y': 413},
#   {'id': 'v34', 'name': '48', 'type': 'flow', 'x': 2120, 'y': 682},
#   {'id': 'v38',
#    'name': 'Cantidad de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2176,
#    'y': 571},
#   {'id': 'v39',
#    'name': 'Disponibilidad de talleres',
#    'type': 'auxiliary',
#    'x': 1346,
#    'y': 1151},
#   {'id': 'v40', 'name': '48', 'type': 'flow', 'x': 954, 'y': 1134},
#   {'id': 'v44',
#    'name': 'Cantidad de plazas sin asignacion de mantenimiento',
#    'type': 'auxiliary',
#    'x': 1127,
#    'y': 1170},
#   {'id': 'v45', 'name': '48', 'type': 'flow', 'x': 1679, 'y': 1150},
#   {'id': 'v49',
#    'name': 'Cantidad de plazas apartadas por mantenimiento',
#    'type': 'auxiliary',
#    'x': 1546,
#    'y': 1188},
#   {'id': 'v50',
#    'name': 'Tiempo promedio de mantenimiento',
#    'type': 'auxiliary',
#    'x': 383,
#    'y': 731},
#   {'id': 'v51',
#    'name': 'Tasa de liberacion de plazas',
#    'type': 'auxiliary',
#    'x': 748,
#    'y': 805},
#   {'id': 'v52',
#    'name': 'Cantidad de vehiculos que terminan el mantenimiento por semana',
#    'type': 'auxiliary',
#    'x': 503,
#    'y': 967},
#   {'id': 'v53',
#    'name': 'Total de plazas',
#    'type': 'auxiliary',
#    'x': 942,
#    'y': 1228},
#   {'id': 'v54',
#    'name': 'Cantidad de plazas ocupadas',
#    'type': 'auxiliary',
#    'x': 962,
#    'y': 1319},
#   {'id': 'v55',
#    'name': 'Capacidad de atencion por plaza',
#    'type': 'auxiliary',
#    'x': 1791,
#    'y': 1231},
#   {'id': 'v56',
#    'name': 'Demanda por mantenimiento',
#    'type': 'auxiliary',
#    'x': 1821,
#    'y': 1018},
#   {'id': 'v57',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento preventivo',
#    'type': 'auxiliary',
#    'x': 2135,
#    'y': 820},
#   {'id': 'v58',
#    'name': 'Proporcion de vehiculos que van a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 1612,
#    'y': 783},
#   {'id': 'v59',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 1881,
#    'y': 505},
#   {'id': 'v60',
#    'name': 'Cantidad promedio de malas maniobras por vehiculo',
#    'type': 'auxiliary',
#    'x': 1423,
#    'y': 359},
#   {'id': 'v61',
#    'name': 'Cantidad de malas maniobras',
#    'type': 'auxiliary',
#    'x': 1169,
#    'y': 334},
#   {'id': 'v62',
#    'name': 'Tasa de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 1038,
#    'y': 173},
#   {'id': 'v63',
#    'name': 'Vehiculos operativos que mostraron fallas',
#    'type': 'auxiliary',
#    'x': 951,
#    'y': 267},
#   {'id': 'v64',
#    'name': 'Tasa de inoperatividad por fallas',
#    'type': 'auxiliary',
#    'x': 841,
#    'y': 106},
#   {'id': 'v65',
#    'name': 'Total de la flota',
#    'type': 'auxiliary',
#    'x': 116,
#    'y': 394},
#   {'id': 'v66',
#    'name': 'Cantidad de vehiculos en mantenimiento',
#    'type': 'auxiliary',
#    'x': 276,
#    'y': 246},
#   {'id': 'v67',
#    'name': 'Tasa de asignacion',
#    'type': 'auxiliary',
#    'x': 493,
#    'y': 515},
#   {'id': 'v68',
#    'name': 'Tasa de retorno al deposito',
#    'type': 'auxiliary',
#    'x': 1111,
#    'y': 751},
#   {'id': 'v99',
#    'name': 'Demanda de operacion',
#    'type': 'auxiliary',
#    'x': 529,
#    'y': 649},
#   {'id': 'v103',
#    'name': 'Tasa de reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2376,
#    'y': 267},
#   {'id': 'v105',
#    'name': 'Tasa de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2281,
#    'y': 676},
#   {'id': 'v107',
#    'name': 'Objetivo2',
#    'type': 'auxiliary',
#    'x': 1864,
#    'y': 215},
#   {'id': 'v108',
#    'name': 'Discrepancia2',
#    'type': 'auxiliary',
#    'x': 1979,
#    'y': 264},
#   {'id': 'v109',
#    'name': 'Error/Faltante2',
#    'type': 'auxiliary',
#    'x': 1785,
#    'y': 291},
#   {'id': 'v114',
#    'name': 'Discrepancia1',
#    'type': 'auxiliary',
#    'x': 718,
#    'y': 169},
#   {'id': 'v115', 'name': 'Objetivo1', 'type': 'auxiliary', 'x': 589, 'y': 73},
#   {'id': 'v116',
#    'name': 'Error/Faltante1',
#    'type': 'auxiliary',
#    'x': 483,
#    'y': 191},
#   {'id': 'v117',
#    'name': 'Discrepancia3',
#    'type': 'auxiliary',
#    'x': 671,
#    'y': 644},
#   {'id': 'v118', 'name': 'Objetivo3', 'type': 'auxiliary', 'x': 781, 'y': 736},
#   {'id': 'v119',
#    'name': 'Error/Faltante3',
#    'type': 'auxiliary',
#    'x': 928,
#    'y': 663},
#   {'id': 'v126',
#    'name': 'Discrepancia4',
#    'type': 'auxiliary',
#    'x': 1339,
#    'y': 1286},
#   {'id': 'v127',
#    'name': 'Objetivo4',
#    'type': 'auxiliary',
#    'x': 1418,
#    'y': 1351},
#   {'id': 'v128',
#    'name': 'Error/Faltante4',
#    'type': 'auxiliary',
#    'x': 1552,
#    'y': 1301}],
#  'connections': [{'id': 'c4',
#    'from': 'v6',
#    'to': 'v3',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 400,
#    'y_curve': 336},
#   {'id': 'c5',
#    'from': 'v6',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 517,
#    'y_curve': 336},
#   {'id': 'c9',
#    'from': 'v11',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 755,
#    'y_curve': 343},
#   {'id': 'c10',
#    'from': 'v11',
#    'to': 'v8',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 866,
#    'y_curve': 343},
#   {'id': 'c14',
#    'from': 'v16',
#    'to': 'v2',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 625,
#    'y_curve': 434},
#   {'id': 'c15',
#    'from': 'v16',
#    'to': 'v13',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 625,
#    'y_curve': 582},
#   {'id': 'c19',
#    'from': 'v21',
#    'to': 'v13',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1010,
#    'y_curve': 589},
#   {'id': 'c20',
#    'from': 'v21',
#    'to': 'v18',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1146,
#    'y_curve': 589},
#   {'id': 'c25',
#    'from': 'v27',
#    'to': 'v24',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1702,
#    'y_curve': 386},
#   {'id': 'c26',
#    'from': 'v27',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1869,
#    'y_curve': 386},
#   {'id': 'c30',
#    'from': 'v32',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2155,
#    'y_curve': 381},
#   {'id': 'c31',
#    'from': 'v32',
#    'to': 'v29',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2291,
#    'y_curve': 381},
#   {'id': 'c35',
#    'from': 'v37',
#    'to': 'v23',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2046,
#    'y_curve': 488},
#   {'id': 'c36',
#    'from': 'v37',
#    'to': 'v34',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2046,
#    'y_curve': 682},
#   {'id': 'c41',
#    'from': 'v43',
#    'to': 'v40',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1056,
#    'y_curve': 1134},
#   {'id': 'c42',
#    'from': 'v43',
#    'to': 'v39',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1206,
#    'y_curve': 1134},
#   {'id': 'c46',
#    'from': 'v48',
#    'to': 'v39',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1476,
#    'y_curve': 1150},
#   {'id': 'c47',
#    'from': 'v48',
#    'to': 'v45',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1610,
#    'y_curve': 1150},
#   {'id': 'c69',
#    'from': 'v2',
#    'to': 'v66',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 483,
#    'y_curve': 223},
#   {'id': 'c70',
#    'from': 'v66',
#    'to': 'v6',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 417,
#    'y_curve': 284},
#   {'id': 'c71',
#    'from': 'v65',
#    'to': 'v66',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 227,
#    'y_curve': 364},
#   {'id': 'c72',
#    'from': 'v50',
#    'to': 'v7',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c73',
#    'from': 'v50',
#    'to': 'v51',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c74',
#    'from': 'v52',
#    'to': 'v51',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 702,
#    'y_curve': 915},
#   {'id': 'c75',
#    'from': 'v39',
#    'to': 'v54',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1221,
#    'y_curve': 1304},
#   {'id': 'c76',
#    'from': 'v55',
#    'to': 'v49',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c77',
#    'from': 'v56',
#    'to': 'v48',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1677,
#    'y_curve': 1177},
#   {'id': 'c78',
#    'from': 'v57',
#    'to': 'v56',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2024,
#    'y_curve': 952},
#   {'id': 'c79',
#    'from': 'v57',
#    'to': 'v37',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2134,
#    'y_curve': 710},
#   {'id': 'c80',
#    'from': 'v58',
#    'to': 'v57',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c81',
#    'from': 'v59',
#    'to': 'v56',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c82',
#    'from': 'v58',
#    'to': 'v59',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c83',
#    'from': 'v59',
#    'to': 'v32',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2038,
#    'y_curve': 504},
#   {'id': 'c84',
#    'from': 'v62',
#    'to': 'v27',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1567,
#    'y_curve': 124},
#   {'id': 'c85',
#    'from': 'v61',
#    'to': 'v28',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1577,
#    'y_curve': 208},
#   {'id': 'c86',
#    'from': 'v60',
#    'to': 'v61',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1292,
#    'y_curve': 397},
#   {'id': 'c87',
#    'from': 'v13',
#    'to': 'v61',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c88',
#    'from': 'v13',
#    'to': 'v21',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1008,
#    'y_curve': 556},
#   {'id': 'c89',
#    'from': 'v68',
#    'to': 'v22',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1126,
#    'y_curve': 650},
#   {'id': 'c90',
#    'from': 'v13',
#    'to': 'v63',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 962,
#    'y_curve': 437},
#   {'id': 'c91',
#    'from': 'v62',
#    'to': 'v63',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 971,
#    'y_curve': 172},
#   {'id': 'c92',
#    'from': 'v64',
#    'to': 'v11',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c93',
#    'from': 'v63',
#    'to': 'v11',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c94',
#    'from': 'v12',
#    'to': 'v59',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c95',
#    'from': 'v12',
#    'to': 'v57',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c96',
#    'from': 'v2',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 680,
#    'y_curve': 422},
#   {'id': 'c97',
#    'from': 'v67',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 560,
#    'y_curve': 471},
#   {'id': 'c98',
#    'from': 'v53',
#    'to': 'v54',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 977,
#    'y_curve': 1265},
#   {'id': 'c100',
#    'from': 'v99',
#    'to': 'v16',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c101',
#    'from': 'v54',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1079,
#    'y_curve': 1278},
#   {'id': 'c102',
#    'from': 'v51',
#    'to': 'v43',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c104',
#    'from': 'v103',
#    'to': 'v32',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 2242,
#    'y_curve': 249},
#   {'id': 'c106',
#    'from': 'v105',
#    'to': 'v37',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c110',
#    'from': 'v107',
#    'to': 'v108',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1947,
#    'y_curve': 221},
#   {'id': 'c111',
#    'from': 'v107',
#    'to': 'v109',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1793,
#    'y_curve': 244},
#   {'id': 'c112',
#    'from': 'v23',
#    'to': 'v109',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1913,
#    'y_curve': 322},
#   {'id': 'c113',
#    'from': 'v23',
#    'to': 'v108',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c120',
#    'from': 'v2',
#    'to': 'v114',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c121',
#    'from': 'v2',
#    'to': 'v116',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 602,
#    'y_curve': 235},
#   {'id': 'c122',
#    'from': 'v115',
#    'to': 'v114',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 681,
#    'y_curve': 93},
#   {'id': 'c123',
#    'from': 'v115',
#    'to': 'v116',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 505,
#    'y_curve': 93},
#   {'id': 'c124',
#    'from': 'v13',
#    'to': 'v117',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 743,
#    'y_curve': 642},
#   {'id': 'c125',
#    'from': 'v13',
#    'to': 'v119',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 824,
#    'y_curve': 652},
#   {'id': 'c129',
#    'from': 'v39',
#    'to': 'v126',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c130',
#    'from': 'v39',
#    'to': 'v128',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 0,
#    'y_curve': 0},
#   {'id': 'c131',
#    'from': 'v118',
#    'to': 'v117',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 693,
#    'y_curve': 712},
#   {'id': 'c132',
#    'from': 'v118',
#    'to': 'v119',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 879,
#    'y_curve': 721},
#   {'id': 'c133',
#    'from': 'v127',
#    'to': 'v126',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1314,
#    'y_curve': 1361},
#   {'id': 'c134',
#    'from': 'v127',
#    'to': 'v128',
#    'color': None,
#    'polarity': 'positive',
#    'x_curve': 1513,
#    'y_curve': 1360}]}

# %%
model = read_vensim('satisfaccion_autoridades-forrester.mdl')

# %%
model.doc
# Out:
#                                     Real Name  \
# 0                      Accidentes de tránsito
# 1                       Accidentes prevenidos
# 2             Calidad de infraestructura vial
# 3                      Cantidad de accidentes
# 4                           Confianza pública
# 5                        Congestion vehicular
# 6                   Depreciacion de inversion
# 7                         Deterioro de imagen
# 8                Deterioro de infraestructura
# 9                                  FINAL TIME
# 10                        Fluidez del trafico
# 11                         Flujo de inversion
# 12                               INITIAL TIME
# 13              Imagen pública de autoridades
# 14                   Infracciones vehiculares
# 15               Inversion en infraestructura
# 16                           Mejora de imagen
# 17                  Mejora de infraestructura
# 18            Pagos de tributos de transporte
# 19                       Perdida de confianza
# 20                    Porcentaje de inversion
# 21                         Quejas de usuarios
# 22                  Recuperacion de confianza
# 23                                    SAVEPER
# 24  Satisfaccion de autoridades de transporte
# 25                   Satisfaccion de usuarios
# 26                                  TIME STEP
# 27                 Tasa de quejas de usuarios
# 28                        Tasa de recaudacion
# 29               Tasa de viajes de transporte
# 30                                       Time
# 31                  Total regulaciones viales
#
#                                       Py Name Subscripts  Units      Limits  \
# 0                      accidentes_de_transito       None   None  (nan, nan)
# 1                       accidentes_prevenidos       None   None  (nan, nan)
# 2             calidad_de_infraestructura_vial       None   None  (nan, nan)
# 3                      cantidad_de_accidentes       None   None  (nan, nan)
# 4                           confianza_publica       None   None  (nan, nan)
# 5                        congestion_vehicular       None   None  (nan, nan)
# 6                   depreciacion_de_inversion       None   None  (nan, nan)
# 7                         deterioro_de_imagen       None   None  (nan, nan)
# 8                deterioro_de_infraestructura       None   None  (nan, nan)
# 9                                  final_time       None  Month  (nan, nan)
# 10                        fluidez_del_trafico       None   None  (nan, nan)
# 11                         flujo_de_inversion       None   None  (nan, nan)
# 12                               initial_time       None  Month  (nan, nan)
# 13              imagen_publica_de_autoridades       None   None  (nan, nan)
# 14                   infracciones_vehiculares       None   None  (nan, nan)
# 15               inversion_en_infraestructura       None   None  (nan, nan)
# 16                           mejora_de_imagen       None   None  (nan, nan)
# 17                  mejora_de_infraestructura       None   None  (nan, nan)
# 18            pagos_de_tributos_de_transporte       None   None  (nan, nan)
# 19                       perdida_de_confianza       None   None  (nan, nan)
# 20                    porcentaje_de_inversion       None   None  (nan, nan)
# 21                         quejas_de_usuarios       None   None  (nan, nan)
# 22                  recuperacion_de_confianza       None   None  (nan, nan)
# 23                                    saveper       None  Month  (0.0, nan)
# 24  satisfaccion_de_autoridades_de_transporte       None   None  (nan, nan)
# 25                   satisfaccion_de_usuarios       None   None  (nan, nan)
# 26                                  time_step       None  Month  (0.0, nan)
# 27                 tasa_de_quejas_de_usuarios       None   None  (nan, nan)
# 28                        tasa_de_recaudacion       None   None  (nan, nan)
# 29               tasa_de_viajes_de_transporte       None   None  (nan, nan)
# 30                                       time       None   None  (nan, nan)
# 31                  total_regulaciones_viales       None   None  (nan, nan)
#
#          Type Subtype                                     Comment
# 0    Stateful   Integ                                        None
# 1   Auxiliary  Normal                                        None
# 2    Stateful   Integ                                        None
# 3   Auxiliary  Normal                                        None
# 4    Stateful   Integ                                        None
# 5   Auxiliary  Normal                                        None
# 6   Auxiliary  Normal                                        None
# 7   Auxiliary  Normal                                        None
# 8   Auxiliary  Normal                                        None
# 9    Constant  Normal          The final time for the simulation.
# 10  Auxiliary  Normal                                        None
# 11  Auxiliary  Normal                                        None
# 12   Constant  Normal        The initial time for the simulation.
# 13   Stateful   Integ                                        None
# 14  Auxiliary  Normal                                        None
# 15   Stateful   Integ                                        None
# 16  Auxiliary  Normal                                        None
# 17  Auxiliary  Normal                                        None
# 18  Auxiliary  Normal                                        None
# 19  Auxiliary  Normal                                        None
# 20   Constant  Normal                                        None
# 21  Auxiliary  Normal                                        None
# 22  Auxiliary  Normal                                        None
# 23  Auxiliary  Normal  The frequency with which output is stored.
# 24  Auxiliary  Normal                                        None
# 25  Auxiliary  Normal                                        None
# 26   Constant  Normal           The time step for the simulation.
# 27  Auxiliary  Normal                                        None
# 28  Auxiliary  Normal                                        None
# 29  Auxiliary  Normal                                        None
# 30       None    None                  Current time of the model.
# 31  Auxiliary  Normal                                        None

# %%
data = model.run()

# %%
data
# Out:
#       FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  Accidentes de tránsito  \
# time
# 2025        2036          2025        1          1             1000.000000
# 2026        2036          2025        1          1              965.031667
# 2027        2036          2025        1          1              929.475574
# 2028        2036          2025        1          1              893.537960
# 2029        2036          2025        1          1              857.412420
# 2030        2036          2025        1          1              821.279113
# 2031        2036          2025        1          1              785.304228
# 2032        2036          2025        1          1              749.639664
# 2033        2036          2025        1          1              714.422922
# 2034        2036          2025        1          1              679.777170
# 2035        2036          2025        1          1              645.811480
# 2036        2036          2025        1          1              612.621192
#
#       Calidad de infraestructura vial  Confianza pública  \
# time
# 2025                        50.000000           0.500000
# 2026                        53.750000           0.499808
# 2027                        57.387500           0.505138
# 2028                        60.915875           0.515906
# 2029                        64.338399           0.532023
# 2030                        67.658247           0.553390
# 2031                        70.878499           0.579905
# 2032                        74.002144           0.611459
# 2033                        77.032080           0.647941
# 2034                        79.971118           0.689233
# 2035                        82.821984           0.735216
# 2036                        85.587325           0.785767
#
#       Congestion vehicular  Depreciacion de inversion  Deterioro de imagen  \
# time
# 2025              0.500000                   0.050000                  0.0
# 2026              0.462500                   0.050037                  2.5
# 2027              0.426125                   0.050074                  2.5
# 2028              0.390841                   0.050112                  2.5
# 2029              0.356616                   0.050149                  2.5
# 2030              0.323418                   0.050186                  2.5
# 2031              0.291215                   0.050223                  2.5
# 2032              0.259979                   0.050261                  2.5
# 2033              0.229679                   0.050298                  2.5
# 2034              0.200289                   0.050335                  2.5
# 2035              0.171780                   0.050372                  2.5
# 2036              0.144127                   0.050410                  0.0
#
#       ...  Porcentaje de inversion  Quejas de usuarios  \
# time  ...
# 2025  ...                      0.3                 0.0
# 2026  ...                      0.3                50.0
# 2027  ...                      0.3                50.0
# 2028  ...                      0.3                50.0
# 2029  ...                      0.3                50.0
# 2030  ...                      0.3                50.0
# 2031  ...                      0.3                50.0
# 2032  ...                      0.3                50.0
# 2033  ...                      0.3                50.0
# 2034  ...                      0.3                50.0
# 2035  ...                      0.3                50.0
# 2036  ...                      0.3                 0.0
#
#       Recuperacion de confianza  Satisfaccion de autoridades de transporte  \
# time
# 2025                   0.049808                                   0.005396
# 2026                   0.053582                                   0.005458
# 2027                   0.057242                                   0.005522
# 2028                   0.060793                                   0.005589
# 2029                   0.064238                                   0.005659
# 2030                   0.067579                                   0.005730
# 2031                   0.070820                                   0.005804
# 2032                   0.073964                                   0.005881
# 2033                   0.077013                                   0.005960
# 2034                   0.079972                                   0.006041
# 2035                   0.082841                                   0.006124
# 2036                   0.085625                                   0.006210
#
#       Satisfaccion de usuarios  Cantidad de accidentes  \
# time
# 2025                  2.485000                0.031667
# 2026                  2.673625                0.029450
# 2027                  2.856591                0.027282
# 2028                  3.034069                0.025162
# 2029                  3.206221                0.023088
# 2030                  3.373210                0.021058
# 2031                  3.535189                0.019071
# 2032                  3.692308                0.017126
# 2033                  3.844714                0.015220
# 2034                  3.992547                0.013352
# 2035                  4.135946                0.011521
# 2036                  4.275042                0.009726
#
#       Tasa de quejas de usuarios  Tasa de recaudacion  \
# time
# 2025                         0.0                   25
# 2026                         0.5                   25
# 2027                         0.5                   25
# 2028                         0.5                   25
# 2029                         0.5                   25
# 2030                         0.5                   25
# 2031                         0.5                   25
# 2032                         0.5                   25
# 2033                         0.5                   25
# 2034                         0.5                   25
# 2035                         0.5                   25
# 2036                         0.0                   25
#
#       Tasa de viajes de transporte  Total regulaciones viales
# time
# 2025                      0.107917                   3.500000
# 2026                      0.109157                   3.687500
# 2027                      0.110447                   3.869375
# 2028                      0.111784                   4.045794
# 2029                      0.113171                   4.216920
# 2030                      0.114605                   4.382912
# 2031                      0.116087                   4.543925
# 2032                      0.117616                   4.700107
# 2033                      0.119193                   4.851604
# 2034                      0.120817                   4.998556
# 2035                      0.122487                   5.141099
# 2036                      0.124204                   5.279366
#
# [12 rows x 31 columns]

# %%
tasa_1 = model.components.inversion_en_infraestructura()

# %%
tasa_1
# Out:
# 10081.947951280734

# %%
# !pip3 install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from plotly.express) (2.3.1)
# Collecting plotly>=4.1.0 (from plotly.express)
#   Downloading plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting statsmodels>=0.9.0 (from plotly.express)
#   Downloading statsmodels-0.14.5-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: scipy>=0.18 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from plotly.express) (1.15.2)
# Collecting patsy>=0.5 (from plotly.express)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.11 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from plotly.express) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\piter\appdata\roaming\python\python311\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from pandas>=0.20.0->plotly.express) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\piter\.conda\envs\analiticadedatos\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Collecting narwhals>=1.15.1 (from plotly>=4.1.0->plotly.express)
#   Downloading narwhals-1.47.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in c:\users\piter\appdata\roaming\python\python311\site-packages (from plotly>=4.1.0->plotly.express) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\piter\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.16.0)
# Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.9 kB ? eta -:--:--
#    -------------------------------------- - 225.3/232.9 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 232.9/232.9 kB 4.8 MB/s eta 0:00:00
# Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/9.6 MB 14.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/9.6 MB 12.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.5/9.6 MB 11.6 MB/s eta 0:00:01
#    -------- ------------------------------- 2.0/9.6 MB 11.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/9.6 MB 11.5 MB/s eta 0:00:01
#    ------------ --------------------------- 3.0/9.6 MB 11.4 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.6 MB 11.7 MB/s eta 0:00:01
#    ------------- -------------------------- 3.3/9.6 MB 9.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.5/9.6 MB 8.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.6 MB 8.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.9/9.6 MB 8.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.1/9.6 MB 7.4 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.6 MB 7.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.6 MB 7.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.6 MB 6.4 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.6 MB 6.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.6 MB 5.8 MB/s eta 0:00:01
#    ------------------- -------------------- 4.6/9.6 MB 5.6 MB/s eta 0:00:01
#    ------------------- -------------------- 4.8/9.6 MB 5.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.6 MB 5.4 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.6 MB 5.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.4/9.6 MB 5.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.6/9.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.6 MB 5.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.1/9.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.6 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 6.7/9.6 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.6 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.7/9.6 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.3/9.6 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.6 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.1/9.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 5.4 MB/s eta 0:00:00
# Downloading statsmodels-0.14.5-cp311-cp311-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.6 MB 656.4 kB/s eta 0:00:15
#     --------------------------------------- 0.1/9.6 MB 1.2 MB/s eta 0:00:08
#     --------------------------------------- 0.2/9.6 MB 1.0 MB/s eta 0:00:10
#     --------------------------------------- 0.2/9.6 MB 807.1 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/9.6 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/9.6 MB 1.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/9.6 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.6 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.6 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.6 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/9.6 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.1/9.6 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.6 MB 2.0 MB/s eta 0:00:05
#    ------ --------------------------------- 1.5/9.6 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.7/9.6 MB 2.3 MB/s eta 0:00:04
#    ------- -------------------------------- 1.9/9.6 MB 2.4 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.6 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.3/9.6 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/9.6 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.8/9.6 MB 2.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.6 MB 3.0 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.6 MB 3.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.6 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.8/9.6 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.8/9.6 MB 3.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.6 MB 3.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.1/9.6 MB 3.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.1/9.6 MB 3.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.1/9.6 MB 3.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.3/9.6 MB 3.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.4/9.6 MB 3.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.6 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.9/9.6 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.6 MB 3.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.4/9.6 MB 3.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.7/9.6 MB 3.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.6 MB 3.4 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.6 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.6 MB 3.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.6 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 7.4/9.6 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 7.7/9.6 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.6 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.0/9.6 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.6 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.6 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.6 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.6 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.8/9.6 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.0/9.6 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 3.8 MB/s eta 0:00:00
# Downloading narwhals-1.47.1-py3-none-any.whl (375 kB)
#    ---------------------------------------- 0.0/375.5 kB ? eta -:--:--
#    ----------------------- ---------------- 225.3/375.5 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 375.5/375.5 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: patsy, narwhals, plotly, statsmodels, plotly.express
# Successfully installed narwhals-1.47.1 patsy-1.0.1 plotly-6.2.0 plotly.express-0.4.1 statsmodels-0.14.5

# %%
import plotly_express as px

# %%
fig = px.line(data, y=["Inversion en infraestructura","Flujo de inversion","Depreciacion de inversion","Porcentaje de inversion","Tasa de recaudacion"],title="Satisfaccion de Autoridades")

# %%
fig.show()

# %%
data = model.run(params={"Tasa de recaudacion": 1})
# Out:
# c:\Users\piter\.conda\envs\AnaliticaDeDatos\Lib\site-packages\pysd\py_backend\model.py:1145: UserWarning:
#
# Replacing a variable by a constant value.

# %%
data
# Out:
#       FINAL TIME  INITIAL TIME  SAVEPER  TIME STEP  Accidentes de tránsito  \
# time
# 2025        2036          2025        1          1             1000.000000
# 2026        2036          2025        1          1              965.031667
# 2027        2036          2025        1          1              931.910429
# 2028        2036          2025        1          1              900.510856
# 2029        2036          2025        1          1              870.717582
# 2030        2036          2025        1          1              842.424392
# 2031        2036          2025        1          1              815.533388
# 2032        2036          2025        1          1              789.954250
# 2033        2036          2025        1          1              765.603564
# 2034        2036          2025        1          1              742.404221
# 2035        2036          2025        1          1              720.284870
# 2036        2036          2025        1          1              699.179428
#
#       Calidad de infraestructura vial  Confianza pública  \
# time
# 2025                        50.000000           0.500000
# 2026                        48.710000           0.499808
# 2027                        47.458700           0.500066
# 2028                        46.244939           0.500721
# 2029                        45.067591           0.501725
# 2030                        43.925563           0.503033
# 2031                        42.817796           0.504607
# 2032                        41.743262           0.506411
# 2033                        40.700964           0.508413
# 2034                        39.689936           0.510583
# 2035                        38.709237           0.512896
# 2036                        37.757960           0.515327
#
#       Congestion vehicular  Depreciacion de inversion  Deterioro de imagen  \
# time
# 2025              0.500000                   0.050000                  0.0
# 2026              0.512900                   0.050001                  2.5
# 2027              0.525413                   0.050002                  2.5
# 2028              0.537551                   0.050004                  2.5
# 2029              0.549324                   0.050005                  2.5
# 2030              0.560744                   0.050006                  2.5
# 2031              0.571822                   0.050007                  2.5
# 2032              0.582567                   0.050009                  2.5
# 2033              0.592990                   0.050010                  2.5
# 2034              0.603101                   0.050011                  2.5
# 2035              0.612908                   0.050012                  2.5
# 2036              0.622420                   0.050014                  0.0
#
#       ...  Porcentaje de inversion  Quejas de usuarios  \
# time  ...
# 2025  ...                      0.3                 0.0
# 2026  ...                      0.3                50.0
# 2027  ...                      0.3                50.0
# 2028  ...                      0.3                50.0
# 2029  ...                      0.3                50.0
# 2030  ...                      0.3                50.0
# 2031  ...                      0.3                50.0
# 2032  ...                      0.3                50.0
# 2033  ...                      0.3                50.0
# 2034  ...                      0.3                50.0
# 2035  ...                      0.3                50.0
# 2036  ...                      0.3                 0.0
#
#       Recuperacion de confianza  Satisfaccion de autoridades de transporte  \
# time
# 2025                   0.049808                                   0.005396
# 2026                   0.048510                                   0.005375
# 2027                   0.047251                                   0.005356
# 2028                   0.046029                                   0.005338
# 2029                   0.044844                                   0.005321
# 2030                   0.043695                                   0.005304
# 2031                   0.042580                                   0.005288
# 2032                   0.041499                                   0.005274
# 2033                   0.040450                                   0.005259
# 2034                   0.039433                                   0.005246
# 2035                   0.038446                                   0.005233
# 2036                   0.037489                                   0.005221
#
#       Satisfaccion de usuarios  Cantidad de accidentes  \
# time
# 2025                  2.485000                0.031667
# 2026                  2.420113                0.032425
# 2027                  2.357173                0.033159
# 2028                  2.296120                0.033870
# 2029                  2.236900                0.034557
# 2030                  2.179456                0.035223
# 2031                  2.123735                0.035867
# 2032                  2.069686                0.036491
# 2033                  2.017259                0.037095
# 2034                  1.966404                0.037679
# 2035                  1.917075                0.038245
# 2036                  1.869225                0.038794
#
#       Tasa de quejas de usuarios  Tasa de recaudacion  \
# time
# 2025                         0.0                    1
# 2026                         0.5                    1
# 2027                         0.5                    1
# 2028                         0.5                    1
# 2029                         0.5                    1
# 2030                         0.5                    1
# 2031                         0.5                    1
# 2032                         0.5                    1
# 2033                         0.5                    1
# 2034                         0.5                    1
# 2035                         0.5                    1
# 2036                         0.0                    1
#
#       Tasa de viajes de transporte  Total regulaciones viales
# time
# 2025                      0.107917                   3.500000
# 2026                      0.107509                   3.435500
# 2027                      0.107124                   3.372935
# 2028                      0.106758                   3.312247
# 2029                      0.106411                   3.253380
# 2030                      0.106081                   3.196278
# 2031                      0.105768                   3.140890
# 2032                      0.105471                   3.087163
# 2033                      0.105187                   3.035048
# 2034                      0.104918                   2.984497
# 2035                      0.104661                   2.935462
# 2036                      0.104417                   2.887898
#
# [12 rows x 31 columns]

# %%
fig = px.line(data, y=["Inversion en infraestructura","Flujo de inversion","Depreciacion de inversion","Porcentaje de inversion","Tasa de recaudacion"],title="Satisfaccion de Autoridades")
fig.show()
