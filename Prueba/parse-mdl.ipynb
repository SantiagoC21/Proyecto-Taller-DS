# %%
import os

# %%
import os

def parse_mdl_file(filepath):
    variables = []
    connections = []
    variable_ids = set()  # Para evitar duplicados

    with open(filepath, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    for line in lines:
        parts = line.strip().split(',')

        if not parts or len(parts) < 5:
            continue

        prefix = parts[0]

        if prefix in ['10', '11', '12']:  # Variable
            try:
                tipo = {
                    '10': 'auxiliary',
                    '11': 'stock',
                    '12': 'flow'
                }[prefix]

                vid = f"v{parts[1]}"
                name = parts[2].strip('"')

                if name == '0' or name.strip() == '':
                    continue  # Ignorar nombres inválidos

                if vid in variable_ids:
                    continue  # Ignorar duplicados

                x = int(parts[3])
                y = int(parts[4])

                variables.append({
                    "id": vid,
                    "name": name,
                    "type": tipo,
                    "x": x,
                    "y": y
                })

                variable_ids.add(vid)

            except Exception as e:
                print("[ERROR variable] Línea inválida:", line.strip(), "→", e)
                continue

        elif prefix == '1' and len(parts) >= 4:  # Connection
            try:
                cid = f"c{parts[1]}"
                from_id = f"v{parts[2]}"
                to_id = f"v{parts[3]}"
                connections.append({
                    "id": cid,
                    "from": from_id,
                    "to": to_id,
                    "polarity": "positive"  # Aún se asume positiva por defecto
                })
            except Exception as e:
                print("[ERROR conexión] Línea inválida:", line.strip(), "→", e)
                continue

    return {
        "name": os.path.basename(filepath),
        "variables": variables,
        "connections": connections
    }

# %%
parse_mdl_file("eficiencia-movilidad-causal.mdl")
# Out:
# {'name': 'eficiencia-movilidad-causal.mdl',
#  'variables': [{'id': 'v3',
#    'name': 'Congestión vehicular',
#    'type': 'auxiliary',
#    'x': 1095,
#    'y': 501},
#   {'id': 'v4',
#    'name': 'Eficiencia de movilidad',
#    'type': 'auxiliary',
#    'x': 962,
#    'y': 712},
#   {'id': 'v6',
#    'name': 'Fluidez del tráfico',
#    'type': 'auxiliary',
#    'x': 674,
#    'y': 690},
#   {'id': 'v8',
#    'name': 'Uso del transporte público',
#    'type': 'auxiliary',
#    'x': 699,
#    'y': 412},
#   {'id': 'v9',
#    'name': 'Número de vehículos en circulación',
#    'type': 'auxiliary',
#    'x': 834,
#    'y': 501},
#   {'id': 'v12',
#    'name': 'Calidad de transporte público',
#    'type': 'auxiliary',
#    'x': 527,
#    'y': 362},
#   {'id': 'v14',
#    'name': 'Extorsionesa a transportistas',
#    'type': 'auxiliary',
#    'x': 356,
#    'y': 237},
#   {'id': 'v15',
#    'name': 'Nivel de educación vial',
#    'type': 'auxiliary',
#    'x': 1359,
#    'y': 214},
#   {'id': 'v16',
#    'name': 'Total de Infracciones',
#    'type': 'auxiliary',
#    'x': 1024,
#    'y': 330},
#   {'id': 'v18',
#    'name': 'Cantidad de Transporte informal',
#    'type': 'auxiliary',
#    'x': 1335,
#    'y': 375},
#   {'id': 'v19',
#    'name': 'Paradas no autorizadas utilizadas por vehiculo',
#    'type': 'auxiliary',
#    'x': 1263,
#    'y': 453},
#   {'id': 'v23',
#    'name': 'Cruces de pistas indevidas por transeuntes',
#    'type': 'auxiliary',
#    'x': 1340,
#    'y': 582},
#   {'id': 'v26',
#    'name': 'Tasa de presión de pasajeros recibidas por conductores',
#    'type': 'auxiliary',
#    'x': 288,
#    'y': 832},
#   {'id': 'v28',
#    'name': 'Póliticas de regulación de transporte',
#    'type': 'auxiliary',
#    'x': 1201,
#    'y': 320},
#   {'id': 'v30',
#    'name': 'Uso de aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 797,
#    'y': 220},
#   {'id': 'v33', 'name': 'Seguridad', 'type': 'auxiliary', 'x': 569, 'y': 121},
#   {'id': 'v36',
#    'name': 'Estres de transportistas',
#    'type': 'auxiliary',
#    'x': 361,
#    'y': 398},
#   {'id': 'v43',
#    'name': 'Calidad de infraestructura vial',
#    'type': 'auxiliary',
#    'x': 405,
#    'y': 624},
#   {'id': 'v46',
#    'name': 'Estratégicas de ejecución de obras',
#    'type': 'auxiliary',
#    'x': 524,
#    'y': 560},
#   {'id': 'v50',
#    'name': 'Tasa de seguridad',
#    'type': 'auxiliary',
#    'x': 472,
#    'y': 30},
#   {'id': 'v52',
#    'name': 'Tasa de infracciones',
#    'type': 'auxiliary',
#    'x': 1007,
#    'y': 174},
#   {'id': 'v54',
#    'name': 'Tasa de extorsiones a transportistas',
#    'type': 'auxiliary',
#    'x': 259,
#    'y': 122},
#   {'id': 'v56',
#    'name': 'Tasa de transeuntes que cruzan indevidamente',
#    'type': 'auxiliary',
#    'x': 1272,
#    'y': 718},
#   {'id': 'v58',
#    'name': 'Tasa de población que utiliza aplicaciones de transporte',
#    'type': 'auxiliary',
#    'x': 835,
#    'y': 88},
#   {'id': 'v60',
#    'name': 'Tasa de inversion de infraestructura',
#    'type': 'auxiliary',
#    'x': 443,
#    'y': 776},
#   {'id': 'v62',
#    'name': 'Tasa de transportes públicos en correcto estado',
#    'type': 'auxiliary',
#    'x': 593,
#    'y': 245},
#   {'id': 'v64',
#    'name': 'Tasa de vehiculos en circulación',
#    'type': 'auxiliary',
#    'x': 721,
#    'y': 583},
#   {'id': 'v66',
#    'name': 'Tasa de educacion vial de calidad',
#    'type': 'auxiliary',
#    'x': 1232,
#    'y': 125}],
#  'connections': [{'id': 'c5',
#    'from': 'v3',
#    'to': 'v4',
#    'polarity': 'positive'},
#   {'id': 'c7', 'from': 'v6', 'to': 'v4', 'polarity': 'positive'},
#   {'id': 'c10', 'from': 'v8', 'to': 'v9', 'polarity': 'positive'},
#   {'id': 'c11', 'from': 'v9', 'to': 'v3', 'polarity': 'positive'},
#   {'id': 'c13', 'from': 'v12', 'to': 'v8', 'polarity': 'positive'},
#   {'id': 'c17', 'from': 'v16', 'to': 'v3', 'polarity': 'positive'},
#   {'id': 'c20', 'from': 'v18', 'to': 'v19', 'polarity': 'positive'},
#   {'id': 'c21', 'from': 'v19', 'to': 'v3', 'polarity': 'positive'},
#   {'id': 'c22', 'from': 'v15', 'to': 'v18', 'polarity': 'positive'},
#   {'id': 'c24', 'from': 'v15', 'to': 'v23', 'polarity': 'positive'},
#   {'id': 'c25', 'from': 'v23', 'to': 'v3', 'polarity': 'positive'},
#   {'id': 'c27', 'from': 'v26', 'to': 'v19', 'polarity': 'positive'},
#   {'id': 'c29', 'from': 'v28', 'to': 'v18', 'polarity': 'positive'},
#   {'id': 'c31', 'from': 'v30', 'to': 'v8', 'polarity': 'positive'},
#   {'id': 'c32', 'from': 'v4', 'to': 'v30', 'polarity': 'positive'},
#   {'id': 'c34', 'from': 'v33', 'to': 'v30', 'polarity': 'positive'},
#   {'id': 'c35', 'from': 'v33', 'to': 'v14', 'polarity': 'positive'},
#   {'id': 'c37', 'from': 'v14', 'to': 'v36', 'polarity': 'positive'},
#   {'id': 'c38', 'from': 'v36', 'to': 'v12', 'polarity': 'positive'},
#   {'id': 'c39', 'from': 'v16', 'to': 'v36', 'polarity': 'positive'},
#   {'id': 'c40', 'from': 'v8', 'to': 'v30', 'polarity': 'positive'},
#   {'id': 'c41', 'from': 'v4', 'to': 'v3', 'polarity': 'positive'},
#   {'id': 'c42', 'from': 'v4', 'to': 'v6', 'polarity': 'positive'},
#   {'id': 'c44', 'from': 'v43', 'to': 'v6', 'polarity': 'positive'},
#   {'id': 'c45', 'from': 'v43', 'to': 'v36', 'polarity': 'positive'},
#   {'id': 'c47', 'from': 'v46', 'to': 'v6', 'polarity': 'positive'},
#   {'id': 'c48', 'from': 'v8', 'to': 'v6', 'polarity': 'positive'},
#   {'id': 'c49', 'from': 'v14', 'to': 'v33', 'polarity': 'positive'},
#   {'id': 'c51', 'from': 'v50', 'to': 'v33', 'polarity': 'positive'},
#   {'id': 'c53', 'from': 'v52', 'to': 'v16', 'polarity': 'positive'},
#   {'id': 'c55', 'from': 'v54', 'to': 'v14', 'polarity': 'positive'},
#   {'id': 'c57', 'from': 'v56', 'to': 'v23', 'polarity': 'positive'},
#   {'id': 'c59', 'from': 'v58', 'to': 'v30', 'polarity': 'positive'},
#   {'id': 'c61', 'from': 'v60', 'to': 'v43', 'polarity': 'positive'},
#   {'id': 'c63', 'from': 'v62', 'to': 'v12', 'polarity': 'positive'},
#   {'id': 'c65', 'from': 'v64', 'to': 'v9', 'polarity': 'positive'},
#   {'id': 'c67', 'from': 'v66', 'to': 'v15', 'polarity': 'positive'},
#   {'id': 'c72', 'from': 'v26', 'to': 'v36', 'polarity': 'positive'}]}

# %%
parse_mdl_file("frecuencia-de-mantenimiento-forrester.mdl")
# Out:
# {'name': 'frecuencia-de-mantenimiento-forrester.mdl',
#  'variables': [{'id': 'v2',
#    'name': 'Disponibilidad de la flota',
#    'type': 'auxiliary',
#    'x': 745,
#    'y': 257},
#   {'id': 'v3', 'name': '48', 'type': 'flow', 'x': 447, 'y': 257},
#   {'id': 'v7',
#    'name': 'Vehiculos que regresan de mantenimiento',
#    'type': 'auxiliary',
#    'x': 549,
#    'y': 295},
#   {'id': 'v8', 'name': '48', 'type': 'flow', 'x': 1031, 'y': 257},
#   {'id': 'v12',
#    'name': 'Vehiculos que se retiran por mantenimiento',
#    'type': 'auxiliary',
#    'x': 922,
#    'y': 299},
#   {'id': 'v13',
#    'name': 'Cantidad de vehiculos en operacion',
#    'type': 'auxiliary',
#    'x': 958,
#    'y': 496},
#   {'id': 'v17',
#    'name': 'Vehiculos asignados a operar',
#    'type': 'auxiliary',
#    'x': 815,
#    'y': 419},
#   {'id': 'v18', 'name': '48', 'type': 'flow', 'x': 1318, 'y': 503},
#   {'id': 'v22',
#    'name': 'Vehiculos devueltos al deposito',
#    'type': 'auxiliary',
#    'x': 1195,
#    'y': 537},
#   {'id': 'v23',
#    'name': 'Cantidad de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2130,
#    'y': 299},
#   {'id': 'v24', 'name': '48', 'type': 'flow', 'x': 1723, 'y': 300},
#   {'id': 'v28',
#    'name': 'Numero de veces que ocurre una falla mecanica',
#    'type': 'auxiliary',
#    'x': 1894,
#    'y': 340},
#   {'id': 'v29', 'name': '48', 'type': 'flow', 'x': 2477, 'y': 295},
#   {'id': 'v33',
#    'name': 'Reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2326,
#    'y': 327},
#   {'id': 'v34', 'name': '48', 'type': 'flow', 'x': 2228, 'y': 596},
#   {'id': 'v38',
#    'name': 'Cantidad de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2284,
#    'y': 485},
#   {'id': 'v39',
#    'name': 'Disponibilidad de talleres',
#    'type': 'auxiliary',
#    'x': 1454,
#    'y': 1065},
#   {'id': 'v40', 'name': '48', 'type': 'flow', 'x': 1062, 'y': 1048},
#   {'id': 'v44',
#    'name': 'Cantidad de plazas sin asignacion de mantenimiento',
#    'type': 'auxiliary',
#    'x': 1235,
#    'y': 1084},
#   {'id': 'v45', 'name': '48', 'type': 'flow', 'x': 1787, 'y': 1064},
#   {'id': 'v49',
#    'name': 'Cantidad de plazas apartadas por mantenimiento',
#    'type': 'auxiliary',
#    'x': 1654,
#    'y': 1102},
#   {'id': 'v50',
#    'name': 'Tiempo promedio de mantenimiento',
#    'type': 'auxiliary',
#    'x': 596,
#    'y': 635},
#   {'id': 'v51',
#    'name': 'Tasa de liberacion de plazas',
#    'type': 'auxiliary',
#    'x': 856,
#    'y': 719},
#   {'id': 'v52',
#    'name': 'Cantidad de vehiculos que terminan el mantenimiento por semana',
#    'type': 'auxiliary',
#    'x': 630,
#    'y': 846},
#   {'id': 'v53',
#    'name': 'Total de plazas',
#    'type': 'auxiliary',
#    'x': 1050,
#    'y': 1142},
#   {'id': 'v54',
#    'name': 'Cantidad de plazas ocupadas',
#    'type': 'auxiliary',
#    'x': 1070,
#    'y': 1233},
#   {'id': 'v55',
#    'name': 'Capacidad de atencion por plaza',
#    'type': 'auxiliary',
#    'x': 1899,
#    'y': 1145},
#   {'id': 'v56',
#    'name': 'Demanda por mantenimiento',
#    'type': 'auxiliary',
#    'x': 1929,
#    'y': 932},
#   {'id': 'v57',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento preventivo',
#    'type': 'auxiliary',
#    'x': 2243,
#    'y': 734},
#   {'id': 'v58',
#    'name': 'Proporcion de vehiculos que van a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 1746,
#    'y': 774},
#   {'id': 'v59',
#    'name': 'Cantidad de vehiculos destinados a mantenimiento correctivo',
#    'type': 'auxiliary',
#    'x': 1989,
#    'y': 419},
#   {'id': 'v60',
#    'name': 'Cantidad promedio de malas maniobras por vehiculo',
#    'type': 'auxiliary',
#    'x': 1238,
#    'y': 446},
#   {'id': 'v61',
#    'name': 'Cantidad de malas maniobras',
#    'type': 'auxiliary',
#    'x': 1217,
#    'y': 344},
#   {'id': 'v62',
#    'name': 'Tasa de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 1146,
#    'y': 87},
#   {'id': 'v63',
#    'name': 'Vehiculos operativos que mostraron fallas',
#    'type': 'auxiliary',
#    'x': 1059,
#    'y': 181},
#   {'id': 'v64',
#    'name': 'Tasa de inoperatividad por fallas',
#    'type': 'auxiliary',
#    'x': 922,
#    'y': 157},
#   {'id': 'v65',
#    'name': 'Total de la flota',
#    'type': 'auxiliary',
#    'x': 301,
#    'y': 278},
#   {'id': 'v66',
#    'name': 'Cantidad de vehiculos en mantenimiento',
#    'type': 'auxiliary',
#    'x': 457,
#    'y': 165},
#   {'id': 'v67',
#    'name': 'Tasa de asignacion',
#    'type': 'auxiliary',
#    'x': 601,
#    'y': 429},
#   {'id': 'v68',
#    'name': 'Tasa de retorno al deposito',
#    'type': 'auxiliary',
#    'x': 1225,
#    'y': 625},
#   {'id': 'v99',
#    'name': 'Demanda de operacion',
#    'type': 'auxiliary',
#    'x': 637,
#    'y': 563},
#   {'id': 'v103',
#    'name': 'Tasa de reparacion de fallas mecanicas',
#    'type': 'auxiliary',
#    'x': 2484,
#    'y': 181},
#   {'id': 'v105',
#    'name': 'Tasa de reparaciones preventivas',
#    'type': 'auxiliary',
#    'x': 2389,
#    'y': 590},
#   {'id': 'v107',
#    'name': 'Objetivo2',
#    'type': 'auxiliary',
#    'x': 1972,
#    'y': 129},
#   {'id': 'v108',
#    'name': 'Discrepancia2',
#    'type': 'auxiliary',
#    'x': 2087,
#    'y': 178},
#   {'id': 'v109',
#    'name': 'Error/Faltante2',
#    'type': 'auxiliary',
#    'x': 1893,
#    'y': 205},
#   {'id': 'v114',
#    'name': 'Discrepancia1',
#    'type': 'auxiliary',
#    'x': 826,
#    'y': 83},
#   {'id': 'v115', 'name': 'Objetivo1', 'type': 'auxiliary', 'x': 693, 'y': 57},
#   {'id': 'v116',
#    'name': 'Error/Faltante1',
#    'type': 'auxiliary',
#    'x': 591,
#    'y': 105},
#   {'id': 'v117',
#    'name': 'Discrepancia3',
#    'type': 'auxiliary',
#    'x': 786,
#    'y': 537},
#   {'id': 'v118', 'name': 'Objetivo3', 'type': 'auxiliary', 'x': 910, 'y': 581},
#   {'id': 'v119',
#    'name': 'Error/Faltante3',
#    'type': 'auxiliary',
#    'x': 1012,
#    'y': 556},
#   {'id': 'v126',
#    'name': 'Discrepancia4',
#    'type': 'auxiliary',
#    'x': 1447,
#    'y': 1200},
#   {'id': 'v127',
#    'name': 'Objetivo4',
#    'type': 'auxiliary',
#    'x': 1526,
#    'y': 1265},
#   {'id': 'v128',
#    'name': 'Error/Faltante4',
#    'type': 'auxiliary',
#    'x': 1660,
#    'y': 1215}],
#  'connections': [{'id': 'c4',
#    'from': 'v6',
#    'to': 'v3',
#    'polarity': 'positive'},
#   {'id': 'c5', 'from': 'v6', 'to': 'v2', 'polarity': 'positive'},
#   {'id': 'c9', 'from': 'v11', 'to': 'v2', 'polarity': 'positive'},
#   {'id': 'c10', 'from': 'v11', 'to': 'v8', 'polarity': 'positive'},
#   {'id': 'c14', 'from': 'v16', 'to': 'v2', 'polarity': 'positive'},
#   {'id': 'c15', 'from': 'v16', 'to': 'v13', 'polarity': 'positive'},
#   {'id': 'c19', 'from': 'v21', 'to': 'v13', 'polarity': 'positive'},
#   {'id': 'c20', 'from': 'v21', 'to': 'v18', 'polarity': 'positive'},
#   {'id': 'c25', 'from': 'v27', 'to': 'v24', 'polarity': 'positive'},
#   {'id': 'c26', 'from': 'v27', 'to': 'v23', 'polarity': 'positive'},
#   {'id': 'c30', 'from': 'v32', 'to': 'v23', 'polarity': 'positive'},
#   {'id': 'c31', 'from': 'v32', 'to': 'v29', 'polarity': 'positive'},
#   {'id': 'c35', 'from': 'v37', 'to': 'v23', 'polarity': 'positive'},
#   {'id': 'c36', 'from': 'v37', 'to': 'v34', 'polarity': 'positive'},
#   {'id': 'c41', 'from': 'v43', 'to': 'v40', 'polarity': 'positive'},
#   {'id': 'c42', 'from': 'v43', 'to': 'v39', 'polarity': 'positive'},
#   {'id': 'c46', 'from': 'v48', 'to': 'v39', 'polarity': 'positive'},
#   {'id': 'c47', 'from': 'v48', 'to': 'v45', 'polarity': 'positive'},
#   {'id': 'c69', 'from': 'v2', 'to': 'v66', 'polarity': 'positive'},
#   {'id': 'c70', 'from': 'v66', 'to': 'v6', 'polarity': 'positive'},
#   {'id': 'c71', 'from': 'v65', 'to': 'v66', 'polarity': 'positive'},
#   {'id': 'c72', 'from': 'v50', 'to': 'v7', 'polarity': 'positive'},
#   {'id': 'c73', 'from': 'v50', 'to': 'v51', 'polarity': 'positive'},
#   {'id': 'c74', 'from': 'v52', 'to': 'v51', 'polarity': 'positive'},
#   {'id': 'c75', 'from': 'v39', 'to': 'v54', 'polarity': 'positive'},
#   {'id': 'c76', 'from': 'v55', 'to': 'v49', 'polarity': 'positive'},
#   {'id': 'c77', 'from': 'v56', 'to': 'v48', 'polarity': 'positive'},
#   {'id': 'c78', 'from': 'v57', 'to': 'v56', 'polarity': 'positive'},
#   {'id': 'c79', 'from': 'v57', 'to': 'v37', 'polarity': 'positive'},
#   {'id': 'c80', 'from': 'v58', 'to': 'v57', 'polarity': 'positive'},
#   {'id': 'c81', 'from': 'v59', 'to': 'v56', 'polarity': 'positive'},
#   {'id': 'c82', 'from': 'v58', 'to': 'v59', 'polarity': 'positive'},
#   {'id': 'c83', 'from': 'v59', 'to': 'v32', 'polarity': 'positive'},
#   {'id': 'c84', 'from': 'v62', 'to': 'v27', 'polarity': 'positive'},
#   {'id': 'c85', 'from': 'v61', 'to': 'v28', 'polarity': 'positive'},
#   {'id': 'c86', 'from': 'v60', 'to': 'v61', 'polarity': 'positive'},
#   {'id': 'c87', 'from': 'v13', 'to': 'v61', 'polarity': 'positive'},
#   {'id': 'c88', 'from': 'v13', 'to': 'v21', 'polarity': 'positive'},
#   {'id': 'c89', 'from': 'v68', 'to': 'v22', 'polarity': 'positive'},
#   {'id': 'c90', 'from': 'v13', 'to': 'v63', 'polarity': 'positive'},
#   {'id': 'c91', 'from': 'v62', 'to': 'v63', 'polarity': 'positive'},
#   {'id': 'c92', 'from': 'v64', 'to': 'v11', 'polarity': 'positive'},
#   {'id': 'c93', 'from': 'v63', 'to': 'v11', 'polarity': 'positive'},
#   {'id': 'c94', 'from': 'v12', 'to': 'v59', 'polarity': 'positive'},
#   {'id': 'c95', 'from': 'v12', 'to': 'v57', 'polarity': 'positive'},
#   {'id': 'c96', 'from': 'v2', 'to': 'v16', 'polarity': 'positive'},
#   {'id': 'c97', 'from': 'v67', 'to': 'v16', 'polarity': 'positive'},
#   {'id': 'c98', 'from': 'v53', 'to': 'v54', 'polarity': 'positive'},
#   {'id': 'c100', 'from': 'v99', 'to': 'v16', 'polarity': 'positive'},
#   {'id': 'c101', 'from': 'v54', 'to': 'v43', 'polarity': 'positive'},
#   {'id': 'c102', 'from': 'v51', 'to': 'v43', 'polarity': 'positive'},
#   {'id': 'c104', 'from': 'v103', 'to': 'v32', 'polarity': 'positive'},
#   {'id': 'c106', 'from': 'v105', 'to': 'v37', 'polarity': 'positive'},
#   {'id': 'c110', 'from': 'v107', 'to': 'v108', 'polarity': 'positive'},
#   {'id': 'c111', 'from': 'v107', 'to': 'v109', 'polarity': 'positive'},
#   {'id': 'c112', 'from': 'v23', 'to': 'v109', 'polarity': 'positive'},
#   {'id': 'c113', 'from': 'v23', 'to': 'v108', 'polarity': 'positive'},
#   {'id': 'c120', 'from': 'v2', 'to': 'v114', 'polarity': 'positive'},
#   {'id': 'c121', 'from': 'v2', 'to': 'v116', 'polarity': 'positive'},
#   {'id': 'c122', 'from': 'v115', 'to': 'v114', 'polarity': 'positive'},
#   {'id': 'c123', 'from': 'v115', 'to': 'v116', 'polarity': 'positive'},
#   {'id': 'c124', 'from': 'v13', 'to': 'v117', 'polarity': 'positive'},
#   {'id': 'c125', 'from': 'v13', 'to': 'v119', 'polarity': 'positive'},
#   {'id': 'c129', 'from': 'v39', 'to': 'v126', 'polarity': 'positive'},
#   {'id': 'c130', 'from': 'v39', 'to': 'v128', 'polarity': 'positive'},
#   {'id': 'c131', 'from': 'v118', 'to': 'v117', 'polarity': 'positive'},
#   {'id': 'c132', 'from': 'v118', 'to': 'v119', 'polarity': 'positive'},
#   {'id': 'c133', 'from': 'v127', 'to': 'v126', 'polarity': 'positive'},
#   {'id': 'c134', 'from': 'v127', 'to': 'v128', 'polarity': 'positive'}]}

# %%
parse_mdl_file("seguridad-vial-forrester.mdl")
# Out:
# {'name': 'seguridad-vial-forrester.mdl',
#  'variables': [{'id': 'v1',
#    'name': 'Infraestructura de seguridad vial',
#    'type': 'auxiliary',
#    'x': 1093,
#    'y': 244},
#   {'id': 'v2', 'name': '48', 'type': 'flow', 'x': 808, 'y': 252},
#   {'id': 'v6',
#    'name': 'Infraestructura de seguridad vial en ejecución',
#    'type': 'auxiliary',
#    'x': 926,
#    'y': 290},
#   {'id': 'v7', 'name': '48', 'type': 'flow', 'x': 1405, 'y': 248},
#   {'id': 'v11',
#    'name': 'Infraestructura de seguridad vial obsoleta',
#    'type': 'auxiliary',
#    'x': 1284,
#    'y': 286},
#   {'id': 'v12',
#    'name': 'Tasa Infraestructura Seguridad Vial Obsoletas',
#    'type': 'auxiliary',
#    'x': 1497,
#    'y': 356},
#   {'id': 'v13',
#    'name': 'Tasa Ejecucion Seguridad Vial',
#    'type': 'auxiliary',
#    'x': 706,
#    'y': 342},
#   {'id': 'v14',
#    'name': 'Gastos Totales Infraestructura seguridad vial',
#    'type': 'auxiliary',
#    'x': 686,
#    'y': 155},
#   {'id': 'v15',
#    'name': 'Servicios tecnicos para seguridad vial',
#    'type': 'auxiliary',
#    'x': 1307,
#    'y': 88},
#   {'id': 'v16',
#    'name': 'Equipamiento vial adquirida',
#    'type': 'auxiliary',
#    'x': 925,
#    'y': 78},
#   {'id': 'v26',
#    'name': 'Infraestructura en mantenimiento',
#    'type': 'auxiliary',
#    'x': 646,
#    'y': 535},
#   {'id': 'v27', 'name': '48', 'type': 'flow', 'x': 420, 'y': 538},
#   {'id': 'v30', 'name': '48', 'type': 'flow', 'x': 881, 'y': 540},
#   {'id': 'v34',
#    'name': 'Secciones reparadas',
#    'type': 'auxiliary',
#    'x': 779,
#    'y': 574},
#   {'id': 'v36',
#    'name': 'Secciones retiradas para mantenimiento',
#    'type': 'auxiliary',
#    'x': 473,
#    'y': 572},
#   {'id': 'v37',
#    'name': 'Presupuesto mantenimiento de infraestructura',
#    'type': 'auxiliary',
#    'x': 1142,
#    'y': 655},
#   {'id': 'v38', 'name': '48', 'type': 'flow', 'x': 1418, 'y': 648},
#   {'id': 'v42',
#    'name': 'Gastos en mantenimiento',
#    'type': 'auxiliary',
#    'x': 1301,
#    'y': 682},
#   {'id': 'v43', 'name': '48', 'type': 'flow', 'x': 856, 'y': 656},
#   {'id': 'v47',
#    'name': 'Fondos asignados para mantenimiento',
#    'type': 'auxiliary',
#    'x': 975,
#    'y': 690},
#   {'id': 'v48',
#    'name': 'Dispositivos viales operativos',
#    'type': 'auxiliary',
#    'x': 1443,
#    'y': 482},
#   {'id': 'v49', 'name': '48', 'type': 'flow', 'x': 1190, 'y': 488},
#   {'id': 'v52', 'name': '48', 'type': 'flow', 'x': 1700, 'y': 484},
#   {'id': 'v56',
#    'name': 'Dispositivos de seguridad vial retirados por falla',
#    'type': 'auxiliary',
#    'x': 1578,
#    'y': 524},
#   {'id': 'v58',
#    'name': 'Dispositivos de seguridad vial instalados nuevos',
#    'type': 'auxiliary',
#    'x': 1309,
#    'y': 522},
#   {'id': 'v59',
#    'name': 'Tasa de retiro de dispositivos por falla',
#    'type': 'auxiliary',
#    'x': 1677,
#    'y': 624},
#   {'id': 'v62',
#    'name': 'Tasa de reparación de infraestructura seguridad',
#    'type': 'auxiliary',
#    'x': 877,
#    'y': 457},
#   {'id': 'v65',
#    'name': 'Tasa de mantenimiento correctivo seguridad',
#    'type': 'auxiliary',
#    'x': 422,
#    'y': 647},
#   {'id': 'v68',
#    'name': 'Tasa de instalación de nuevos dispositivos',
#    'type': 'auxiliary',
#    'x': 1206,
#    'y': 410},
#   {'id': 'v71',
#    'name': 'Tasa de mantenimiento infraestructura',
#    'type': 'auxiliary',
#    'x': 834,
#    'y': 767},
#   {'id': 'v76',
#    'name': 'Costo promedio mantenimiento infraestructura',
#    'type': 'auxiliary',
#    'x': 1474,
#    'y': 750}],
#  'connections': [{'id': 'c3',
#    'from': 'v5',
#    'to': 'v2',
#    'polarity': 'positive'},
#   {'id': 'c4', 'from': 'v5', 'to': 'v1', 'polarity': 'positive'},
#   {'id': 'c8', 'from': 'v10', 'to': 'v1', 'polarity': 'positive'},
#   {'id': 'c9', 'from': 'v10', 'to': 'v7', 'polarity': 'positive'},
#   {'id': 'c17', 'from': 'v13', 'to': 'v6', 'polarity': 'positive'},
#   {'id': 'c18', 'from': 'v12', 'to': 'v11', 'polarity': 'positive'},
#   {'id': 'c19', 'from': 'v1', 'to': 'v6', 'polarity': 'positive'},
#   {'id': 'c20', 'from': 'v1', 'to': 'v11', 'polarity': 'positive'},
#   {'id': 'c21', 'from': 'v6', 'to': 'v14', 'polarity': 'positive'},
#   {'id': 'c22', 'from': 'v15', 'to': 'v14', 'polarity': 'positive'},
#   {'id': 'c23', 'from': 'v16', 'to': 'v14', 'polarity': 'positive'},
#   {'id': 'c24', 'from': 'v1', 'to': 'v16', 'polarity': 'positive'},
#   {'id': 'c25', 'from': 'v1', 'to': 'v15', 'polarity': 'positive'},
#   {'id': 'c28', 'from': 'v35', 'to': 'v27', 'polarity': 'positive'},
#   {'id': 'c29', 'from': 'v35', 'to': 'v26', 'polarity': 'positive'},
#   {'id': 'c31', 'from': 'v33', 'to': 'v26', 'polarity': 'positive'},
#   {'id': 'c32', 'from': 'v33', 'to': 'v30', 'polarity': 'positive'},
#   {'id': 'c39', 'from': 'v41', 'to': 'v37', 'polarity': 'positive'},
#   {'id': 'c40', 'from': 'v41', 'to': 'v38', 'polarity': 'positive'},
#   {'id': 'c44', 'from': 'v46', 'to': 'v43', 'polarity': 'positive'},
#   {'id': 'c45', 'from': 'v46', 'to': 'v37', 'polarity': 'positive'},
#   {'id': 'c50', 'from': 'v57', 'to': 'v49', 'polarity': 'positive'},
#   {'id': 'c51', 'from': 'v57', 'to': 'v48', 'polarity': 'positive'},
#   {'id': 'c53', 'from': 'v55', 'to': 'v48', 'polarity': 'positive'},
#   {'id': 'c54', 'from': 'v55', 'to': 'v52', 'polarity': 'positive'},
#   {'id': 'c60', 'from': 'v59', 'to': 'v56', 'polarity': 'positive'},
#   {'id': 'c61', 'from': 'v48', 'to': 'v55', 'polarity': 'positive'},
#   {'id': 'c63', 'from': 'v62', 'to': 'v33', 'polarity': 'positive'},
#   {'id': 'c64', 'from': 'v26', 'to': 'v33', 'polarity': 'positive'},
#   {'id': 'c66', 'from': 'v65', 'to': 'v36', 'polarity': 'positive'},
#   {'id': 'c67', 'from': 'v26', 'to': 'v35', 'polarity': 'positive'},
#   {'id': 'c69', 'from': 'v68', 'to': 'v57', 'polarity': 'positive'},
#   {'id': 'c70', 'from': 'v48', 'to': 'v57', 'polarity': 'positive'},
#   {'id': 'c72', 'from': 'v71', 'to': 'v47', 'polarity': 'positive'},
#   {'id': 'c73', 'from': 'v37', 'to': 'v46', 'polarity': 'positive'},
#   {'id': 'c74', 'from': 'v42', 'to': 'v14', 'polarity': 'positive'},
#   {'id': 'c75', 'from': 'v26', 'to': 'v41', 'polarity': 'positive'},
#   {'id': 'c77', 'from': 'v76', 'to': 'v42', 'polarity': 'positive'},
#   {'id': 'c78', 'from': 'v48', 'to': 'v14', 'polarity': 'positive'},
#   {'id': 'c79', 'from': 'v68', 'to': 'v14', 'polarity': 'positive'}]}
